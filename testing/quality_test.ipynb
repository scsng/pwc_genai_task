# %% [markdown]
# # Quality Testing for Agentic Workflow
#
# This notebook tests the quality of the LangGraph agentic workflow by:
# - Reading questions from `input/quality.csv`
# - Running **all questions in parallel** through the workflow to generate answers
# - Evaluating answers using Google Gemini 2.5 Flash for quality metrics:
#   - **Correctness (1-5)**: Factual accuracy of the answer
#   - **Fluency (1-5)**: Language quality and readability
#   - **Relevance (1-5)**: How well the answer addresses the question
#   - **Coverage (1-5)**: Completeness of the answer
# - Saving results to `output/out_quality.csv`

# %%
import sys
import os
import pandas as pd
from pathlib import Path
from tqdm.notebook import tqdm
import json
import concurrent.futures
from threading import Lock

# Add project root to path
project_root = Path(os.getcwd()).parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from dotenv import load_dotenv
load_dotenv(project_root / ".env", override=True)

print(f"Project root: {project_root}")
# Out:
# Project root: /home/scsng/Desktop/Projects/Job_application/pwc/pwc_genai_task

# %%
from utils.chat_client import ChatClient
from utils.agents.agentic_workflow import AgenticWorkflow
from utils.rag.vector_db import QdrantDB
from google import genai
from google.genai import types

# Initialize chat client for agentic workflow
def get_chat_client():
    return ChatClient(
        base_url=os.getenv("INFERENCE_API_URL"),
        model=os.getenv("MODEL", "default-model"),
        api_key=os.getenv("INFERENCE_API_KEY")
    )

# Initialize agentic workflow
def get_agentic_workflow():
    """Initialize the agentic workflow with LLM."""
    chat_client = get_chat_client()
    max_task_count = int(os.getenv("MAX_TASK_COUNT", "3"))
    return AgenticWorkflow(
        llm=chat_client.llm,
        vector_db=QdrantDB(
            collection_name=os.getenv("COLLECTION_NAME"),
            qdrant_host=os.getenv("QDRANT_HOST"),
            embedding_model=os.getenv("EMBEDDING_MODEL"),
            qdrant_api_key=os.getenv("QDRANT_API_KEY"),
            top_k=int(os.getenv("TOP_K", "4"))
        ),
        max_task_count=max_task_count
    )

# Initialize Gemini client for quality evaluation
def get_gemini_client():
    """Initialize Google Gemini 2.5 Flash client for evaluation."""
    api_key = os.getenv("GOOGLE_API_KEY")
    if not api_key:
        raise ValueError("GOOGLE_API_KEY environment variable must be set")
    return genai.Client(api_key=api_key)

print("Initializing workflow...")
workflow = get_agentic_workflow()
print("Workflow initialized successfully!")

print("Initializing Gemini client...")
gemini_client = get_gemini_client()
print("Gemini client initialized successfully!")
# Out:
# Initializing workflow...
# Workflow initialized successfully!
# Initializing Gemini client...
# Gemini client initialized successfully!
# /home/scsng/Desktop/Projects/Job_application/pwc/pwc_genai_task/.venv/lib/python3.13/site-packages/langchain_qdrant/qdrant.py:921: UserWarning: Api key is used with an insecure connection.
#   client = QdrantClient(**client_options)

# %%
# Load quality test data
input_file = Path("input/quality.csv")
df = pd.read_csv(input_file, sep=";")

print(f"Loaded {len(df)} questions from {input_file}")
print(f"\nColumns: {list(df.columns)}")
df.head()
# Out:
# Loaded 15 questions from input/quality.csv
#
# Columns: ['Topic', 'Complex (yes,no)', 'Question', 'Answer', 'Correctness (1-5)', 'Fluency (1-5)', 'Relevance (1-5)', 'Coverage(1-5)', 'Short review']
#                 Topic Complex (yes,no)  \
# 0        Criminal Law               no
# 1        Criminal Law              yes
# 2           Civil Law               no
# 3           Civil Law              yes
# 4  Public Procurement               no
#
#                                             Question  Answer  \
# 0  What is the principle of legality according to...     NaN
# 1  Explain the difference between intentional and...     NaN
# 2  According to the Civil Code, when does a perso...     NaN
# 3  Distinguish between legal capacity and capacit...     NaN
# 4  What language requirements apply to public pro...     NaN
#
#   Correctness (1-5)  Fluency (1-5)  Relevance (1-5)  Coverage(1-5)  \
# 0               NaN            NaN              NaN            NaN
# 1               NaN            NaN              NaN            NaN
# 2               NaN            NaN              NaN            NaN
# 3               NaN            NaN              NaN            NaN
# 4               NaN            NaN              NaN            NaN
#
#    Short review
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
def generate_answer(question: str) -> str:
    """Generate an answer using the agentic workflow."""
    try:
        answer = workflow.invoke(question)
        return answer
    except Exception as e:
        print(f"Error generating answer: {e}")
        return f"Error: {e}"

# %% [markdown]
# ## Step 1: Generate Answers (Parallel)

# %%
# Process a single question for answer generation
print_lock = Lock()

def generate_single_answer(row_data: tuple) -> dict:
    """Generate answer for a single question."""
    idx, row = row_data
    topic = row.get("Topic", "")
    is_complex = row.get("Complex (yes,no)", "no")
    question = row["Question"]
    reference_answer = row.get("Answer", "")
    
    with print_lock:
        print(f"[Q{idx + 1}] Starting: {question[:60]}...")
    
    # Generate answer using agentic workflow
    generated_answer = generate_answer(question)
    
    with print_lock:
        print(f"[Q{idx + 1}] Done - Answer generated ({len(generated_answer)} chars)")
    
    return {
        "idx": idx,
        "Topic": topic,
        "Complex (yes,no)": is_complex,
        "Question": question,
        "Answer": generated_answer,
        "Reference_Answer": reference_answer
    }

# %%
# Generate answers for all questions in PARALLEL
question_col = "Question"

# Filter out empty rows
df_filtered = df[df[question_col].notna() & (df[question_col].str.strip() != "")].copy()

# Prepare data for parallel processing
rows_to_process = [(idx, row) for idx, row in df_filtered.iterrows()]

print(f"Generating answers for {len(rows_to_process)} questions in PARALLEL...\n")
print("="*60)

# Use ThreadPoolExecutor for parallel execution
MAX_WORKERS = min(len(rows_to_process), 10)  # Process up to 10 questions simultaneously

answers_results = []
with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    # Submit all tasks
    future_to_row = {executor.submit(generate_single_answer, row_data): row_data for row_data in rows_to_process}
    
    # Collect results as they complete
    for future in tqdm(concurrent.futures.as_completed(future_to_row), total=len(rows_to_process), desc="Generating Answers"):
        try:
            result = future.result()
            answers_results.append(result)
        except Exception as e:
            row_data = future_to_row[future]
            print(f"Error processing question {row_data[0]}: {e}")

# Sort results by original index to maintain order
answers_results = sorted(answers_results, key=lambda x: x["idx"])

print("\n" + "="*60)
print(f"Completed generating {len(answers_results)} answers!")
# Out:
# Generating answers for 15 questions in PARALLEL...
#
# ============================================================
# [Q1] Starting: What is the principle of legality according to Section 1 of ...
# [Q2] Starting: Explain the difference between intentional and negligent com...
# [Q3] Starting: According to the Civil Code, when does a person reach majori...
# [Q4] Starting: Distinguish between legal capacity and capacity to act under...
# [Q5] Starting: What language requirements apply to public procurement proce...
# [Q6] Starting: How is 'innovation' defined in the Public Procurement Act, a...
# [Q7] Starting: According to Section 2 of the Labor Code, what specific grou...
# [Q8] Starting: Under what conditions can an employer restrict a worker's pe...
# [Q9] Starting: Describe the core principles of Hungary's statehood includin...
# [Q10] Starting: Compare how the principle of 'good faith and fair dealing' i...
# Generating Answers:   0%|          | 0/15 [00:00<?, ?it/s]
# [Q6] Done - Answer generated (836 chars)
# [Q11] Starting: In which specific cases does Hungarian criminal law apply to...
# [Q7] Done - Answer generated (744 chars)
# [Q12] Starting: What are the requirements for the 'Modellválasztás' (Model S...
# [Q1] Done - Answer generated (388 chars)
# [Q13] Starting: Outline the architectural requirements for the LangGraph wor...
# [Q13] Done - Answer generated (296 chars)
# [Q14] Starting: What is the legal status of a human foetus and who is entitl...
# [Q8] Done - Answer generated (1105 chars)
# [Q15] Starting: What are the rules for integrating 'Tools' and the 'RAG Alre...
# [Q15] Done - Answer generated (296 chars)
# [Q3] Done - Answer generated (2132 chars)
# [Q5] Done - Answer generated (2318 chars)
# [Q2] Done - Answer generated (2393 chars)
# [Q10] Done - Answer generated (2501 chars)
# [Q14] Done - Answer generated (875 chars)
# [Q9] Done - Answer generated (2067 chars)
# [Q11] Done - Answer generated (1010 chars)
# [Q12] Done - Answer generated (2936 chars)
# [Q4] Done - Answer generated (1757 chars)
#
# ============================================================
# Completed generating 15 answers!

# %%
# Preview generated answers
answers_df = pd.DataFrame(answers_results)
print(f"Generated {len(answers_df)} answers\n")

# Show preview
preview_df = answers_df[["idx", "Topic", "Question", "Answer"]].copy()
preview_df["Question"] = preview_df["Question"].str[:50] + "..."
preview_df["Answer"] = preview_df["Answer"].str[:80] + "..."
display(preview_df)
# Out:
# Generated 15 answers
#     idx                Topic  \
# 0     0         Criminal Law
# 1     1         Criminal Law
# 2     2            Civil Law
# 3     3            Civil Law
# 4     4   Public Procurement
# 5     5   Public Procurement
# 6     6            Labor Law
# 7     7            Labor Law
# 8     8      Fundamental Law
# 9     9     Legal Principles
# 10   10         Criminal Law
# 11   11  Agentic RAG Project
# 12   12  Agentic RAG Project
# 13   13            Civil Law
# 14   14  Agentic RAG Project
#
#                                              Question  \
# 0   What is the principle of legality according to...
# 1   Explain the difference between intentional and...
# 2   According to the Civil Code, when does a perso...
# 3   Distinguish between legal capacity and capacit...
# 4   What language requirements apply to public pro...
# 5   How is 'innovation' defined in the Public Proc...
# 6   According to Section 2 of the Labor Code, what...
# 7   Under what conditions can an employer restrict...
# 8   Describe the core principles of Hungary's stat...
# 9   Compare how the principle of 'good faith and f...
# 10  In which specific cases does Hungarian crimina...
# 11  What are the requirements for the 'Modellválas...
# 12  Outline the architectural requirements for the...
# 13  What is the legal status of a human foetus and...
# 14  What are the rules for integrating 'Tools' and...
#
#                                                Answer
# 0   The principle of legality according to Section...
# 1   The difference between intentional and neglige...
# 2   A person reaches majority at the age of 18 acc...
# 3   The legal capacity and capacity to act are two...
# 4   The Hungarian language is the primary language...
# 5   The Public Procurement Act does not explicitly...
# 6   The Hungarian Labor Code covers the following ...
# 7   The Hungarian Labor Code allows an employer to...
# 8   The core principles of Hungary's statehood are...
# 9   The principle of 'good faith and fair dealing'...
# 10  Hungarian criminal law applies to acts committ...
# 11  The requirements for the 'Modellválasztás' (Mo...
# 12  I'm a Hungarian legal assistant that can help ...
# 13  The legal status of a human foetus is not expl...
# 14  I'm a Hungarian legal assistant that can help ...

# %% [markdown]
# ## Step 2: Evaluate Answers with Gemini (Parallel)

# %%
# Quality evaluation prompt for Gemini 2.5 Flash
QUALITY_EVALUATION_PROMPT = """You are an expert evaluator assessing the quality of answers generated by an AI legal assistant.

Given a question and an answer, evaluate the answer on the following criteria (score 1-5 for each):

1. **Correctness (1-5)**: How factually accurate is the answer?
   - 1: Completely incorrect or contains major factual errors
   - 2: Contains significant errors but some correct elements
   - 3: Mostly correct with minor errors
   - 4: Correct with only trivial issues
   - 5: Completely accurate and factually correct

2. **Fluency (1-5)**: How well-written and readable is the answer?
   - 1: Incomprehensible or severely broken language
   - 2: Poor grammar/structure, hard to understand
   - 3: Acceptable but has some awkward phrasing
   - 4: Well-written with minor issues
   - 5: Excellent, professional-quality writing

3. **Relevance (1-5)**: How well does the answer address the question?
   - 1: Completely off-topic or irrelevant
   - 2: Partially relevant but misses the main point
   - 3: Addresses the question but with unnecessary tangents
   - 4: Directly relevant with minor deviations
   - 5: Perfectly addresses exactly what was asked

4. **Coverage (1-5)**: How comprehensive is the answer?
   - 1: Missing almost all important information
   - 2: Covers only a small portion of what's needed
   - 3: Covers main points but lacks important details
   - 4: Comprehensive with minor omissions
   - 5: Complete and thorough coverage

Respond ONLY with a valid JSON object in this exact format:
{"correctness": <1-5>, "fluency": <1-5>, "relevance": <1-5>, "coverage": <1-5>, "review": "<brief 1-2 sentence review>"}

Do not include any other text or explanation outside the JSON."""

def evaluate_answer_quality(question: str, answer: str, topic: str = "", reference_answer: str = "") -> dict:
    """Evaluate answer quality using Google Gemini 2.5 Flash."""
    user_content = f"Topic: {topic}\n\nQuestion: {question}\n\nAnswer to evaluate:\n{answer}"
    
    if reference_answer and pd.notna(reference_answer) and str(reference_answer).strip():
        user_content += f"\n\nReference answer (for context):\n{reference_answer}"
    
    try:
        response = gemini_client.models.generate_content(
            model="gemini-2.5-flash",
            contents=f"{QUALITY_EVALUATION_PROMPT}\n\n{user_content}",
            config=types.GenerateContentConfig(
                temperature=0.1,
                max_output_tokens=3000
            )
        )
        print("result_text ####### ",response.text," #######")
        result_text = response.text.strip()
        # Clean up the response - remove markdown code blocks if present
        if result_text.startswith("```json"):
            result_text = result_text[7:]
        if result_text.startswith("```"):
            result_text = result_text[3:]
        if result_text.endswith("```"):
            result_text = result_text[:-3]
        result_text = result_text.strip()
        
        result = json.loads(result_text)
        return {
            "correctness": int(result.get("correctness", 0)),
            "fluency": int(result.get("fluency", 0)),
            "relevance": int(result.get("relevance", 0)),
            "coverage": int(result.get("coverage", 0)),
            "review": result.get("review", "")
        }
    except json.JSONDecodeError as e:
        print(f"JSON parsing error: {e}")
        return {"correctness": 0, "fluency": 0, "relevance": 0, "coverage": 0, "review": f"Parse error: {e}"}
    except Exception as e:
        print(f"Evaluation error: {e}")
        return {"correctness": 0, "fluency": 0, "relevance": 0, "coverage": 0, "review": f"Error: {e}"}

# %%
# Evaluate a single answer
eval_print_lock = Lock()

def evaluate_single_answer(answer_data: dict) -> dict:
    """Evaluate a single answer with Gemini."""
    idx = answer_data["idx"]
    question = answer_data["Question"]
    answer = answer_data["Answer"]
    topic = answer_data["Topic"]
    reference_answer = answer_data.get("Reference_Answer", "")
    
    with eval_print_lock:
        print(f"[Q{idx + 1}] Evaluating...")
    
    # Evaluate quality using Gemini 2.5 Flash
    quality_scores = evaluate_answer_quality(
        question=question,
        answer=answer,
        topic=topic,
        reference_answer=reference_answer
    )
    print("QUALITY SCORES ####### ",quality_scores," #######")
    
    with eval_print_lock:
        print(f"[Q{idx + 1}] Done - Scores: C={quality_scores['correctness']}, F={quality_scores['fluency']}, "
              f"R={quality_scores['relevance']}, Cov={quality_scores['coverage']}")
    
    return {
        "idx": idx,
        "Topic": topic,
        "Complex (yes,no)": answer_data["Complex (yes,no)"],
        "Question": question,
        "Answer": answer,
        "Correctness (1-5)": quality_scores["correctness"],
        "Fluency (1-5)": quality_scores["fluency"],
        "Relevance (1-5)": quality_scores["relevance"],
        "Coverage(1-5)": quality_scores["coverage"],
        "Short review": quality_scores["review"]
    }

# %%
# Evaluate all answers in PARALLEL
print(f"Evaluating {len(answers_results)} answers with Gemini 2.5 Flash in PARALLEL...\n")
print("="*60)

# Use ThreadPoolExecutor for parallel evaluation
MAX_EVAL_WORKERS = min(len(answers_results), 10)  # Process up to 10 evaluations simultaneously

final_results = []
with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_EVAL_WORKERS) as executor:
    # Submit all evaluation tasks
    future_to_answer = {executor.submit(evaluate_single_answer, answer_data): answer_data for answer_data in answers_results}
    
    # Collect results as they complete
    for future in tqdm(concurrent.futures.as_completed(future_to_answer), total=len(answers_results), desc="Evaluating"):
        try:
            result = future.result()
            print(result)
            final_results.append(result)
        except Exception as e:
            answer_data = future_to_answer[future]
            print(f"Error evaluating question {answer_data['idx']}: {e}")

# Sort results by original index to maintain order
final_results = sorted(final_results, key=lambda x: x["idx"])

# Remove the idx field from results
for r in final_results:
    del r["idx"]

print("\n" + "="*60)
print(f"Completed evaluating {len(final_results)} answers!")
# Out:
# Evaluating 15 answers with Gemini 2.5 Flash in PARALLEL...
#
# ============================================================
# [Q1] Evaluating...
# [Q2] Evaluating...
# [Q3] Evaluating...
# [Q4] Evaluating...
# [Q5] Evaluating...
# [Q6] Evaluating...
# [Q7] Evaluating...
# [Q8] Evaluating...
# [Q9] Evaluating...
# [Q10] Evaluating...
# Evaluating:   0%|          | 0/15 [00:00<?, ?it/s]
# result_text #######  ```json
# {
#   "correctness":  #######
# JSON parsing error: Expecting value: line 1 column 1 (char 0)
# QUALITY SCORES #######  {'correctness': 0, 'fluency': 0, 'relevance': 0, 'coverage': 0, 'review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}  #######
# [Q7] Done - Scores: C=0, F=0, R=0, Cov=0
# [Q11] Evaluating...
# {'idx': 6, 'Topic': 'Labor Law', 'Complex (yes,no)': 'no', 'Question': 'According to Section 2 of the Labor Code, what specific groups and entities are covered by the Act?', 'Answer': "The Hungarian Labor Code covers the following groups and entities:\n\nAn 'employee' is any natural person who works under an employment contract [1]. This includes workers who are at least sixteen years of age [2]. However, persons of at least fifteen years of age receiving full-time school education may enter into an employment relationship during school holidays [3].\n\nAn 'employer' is any person having the capacity to perform legal acts who is party to employment contracts with employees [4].\n\nSources:\n[1] Act I of 2012 on the Labor Code, Page 12, Section 34(1)\n[2] Act I of 2012 on the Labor Code, Page 12, Section 34(2)\n[3] Act I of 2012 on the Labor Code, Page 12, Section 34(2)\n[4] Act I of 2012 on the Labor Code, Page 11, Section 33", 'Correctness (1-5)': 0, 'Fluency (1-5)': 0, 'Relevance (1-5)': 0, 'Coverage(1-5)': 0, 'Short review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}
# result_text #######  ```json
# {
#   "correctness":  #######
# JSON parsing error: Expecting value: line 1 column 1 (char 0)
# QUALITY SCORES #######  {'correctness': 0, 'fluency': 0, 'relevance': 0, 'coverage': 0, 'review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}  #######
# [Q4] Done - Scores: C=0, F=0, R=0, Cov=0
# [Q12] Evaluating...
# {'idx': 3, 'Topic': 'Civil Law', 'Complex (yes,no)': 'yes', 'Question': 'Distinguish between legal capacity and capacity to act under the Civil Code. What specific juridical acts can a minor with limited capacity to act perform without their statutory representative?', 'Answer': "The legal capacity and capacity to act are two distinct concepts under the Civil Code. Legal capacity refers to the ability of a person to enter into legal relationships and perform legal acts, as defined in the Civil Code [1]. This includes the capacity to conclude contracts, make wills, and perform other legal acts. Capacity to act, on the other hand, refers to the ability of a person to perform a specific legal act, such as concluding a contract or making a will [2]. This capacity may be affected by factors such as age, mental capacity, or other circumstances that may impact a person's ability to perform a particular legal act.\n\nIn summary, legal capacity is a broader concept that encompasses the ability to enter into legal relationships and perform legal acts, while capacity to act is a more specific concept that refers to the ability to perform a particular legal act.\n\nA minor with limited capacity to act can perform certain juridical acts without their statutory representative. According to Section 2:15, when making juridical acts that affect the minor himself or his property, statutory representatives shall take the views of the minor having no capacity to act but of sound mind into account in accordance with the age and maturity of the minor [3]. Additionally, minors having limited capacity to act and persons having partially limited capacity to act in terms of juridical acts concerning the establishment of parentage may bring an action subject to the consent of their statutory representative [4].\n\nSources:\n[1] Fundamental law, Page 35, Section X\n[2] Act C of 2012 on the Criminal Code, Page 28, Section X\n[3] Act V of 2013 on the Civil Code, Page 5, Section 2:15\n[4] Act V of 2013 on the Civil Code, Page 133, Section 2(2)", 'Correctness (1-5)': 0, 'Fluency (1-5)': 0, 'Relevance (1-5)': 0, 'Coverage(1-5)': 0, 'Short review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}
# result_text #######  ```json
# {
#   "correct  #######
# JSON parsing error: Expecting value: line 1 column 1 (char 0)
# QUALITY SCORES #######  {'correctness': 0, 'fluency': 0, 'relevance': 0, 'coverage': 0, 'review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}  #######
# [Q2] Done - Scores: C=0, F=0, R=0, Cov=0
# [Q13] Evaluating...
# result_text #######  ```json
# {
#   "correctness":  #######
# JSON parsing error: Expecting value: line 1 column 1 (char 0)
# QUALITY SCORES #######  {'correctness': 0, 'fluency': 0, 'relevance': 0, 'coverage': 0, 'review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}  #######
# [Q5] Done - Scores: C=0, F=0, R=0, Cov=0
# [Q14] Evaluating...
# {'idx': 1, 'Topic': 'Criminal Law', 'Complex (yes,no)': 'yes', 'Question': "Explain the difference between intentional and negligent commission of a criminal offence. How does the 'liability for result' affect qualifying circumstances?", 'Answer': "The difference between intentional and negligent commission of a criminal offence lies in the level of awareness and intent behind the act.\n\nIntentional commission of a criminal offence refers to acts committed with the intention of causing harm or violating the law, as stated in Section 3(1) of the Act C of 2012 on the Criminal Code [1]. On the other hand, negligent commission of a criminal offence refers to acts committed without the intention of causing harm, but still resulting in a violation of the law, as stated in Article XXVIII(4) of the Fundamental law [2].\n\nThe 'liability for result' affects qualifying circumstances in the following ways: Liability for result as a qualifying circumstance is governed by Section 9 of the Act C of 2012 on the Criminal Code [1]. According to this provision, the more severe legal consequences attached to the result of a criminal offence shall only be applied if the perpetrator was at least negligent regarding the result.\n\nAdditionally, liability for hazardous operations is governed by Section 6:535 of the Act V of 2013 on the Civil Code [2], which states that a person carrying out hazardous activities shall compensate for the resulting damage, unless they can prove that the damage was caused by an unavoidable event outside the scope of the hazardous activity.\n\nFurthermore, liability in damages in the event of gratuitous contracts is addressed in Section 6:147 of the Act V of 2013 on the Civil Code [3], which states that the person undertaking the performance of a service free of charge shall be liable for the damage incurred in the subject of the service if the obligee proves that the obligor caused the damage by an intentional breach of contract, or failed to provide information on a substantial characteristic of the service which was unknown to the obligee.\n\nFinally, when establishing responsibility and/or the amount of damages, all circumstances of the case shall be taken into consideration, including those affecting the employee's liability and which may have influenced the safe and proper administration of inventories, as stated in Section 187 of the Act I of 2012 on the Labor Code [4].\n\nSources:\n[1] Act C of 2012 on the Criminal Code, Page 2, Section 3(1)\n[2] Fundamental law, Page 15, Article XXVIII(4)\n[3] Act V of 2013 on the Civil Code, Page 234, Section 6:147\n[4] Act I of 2012 on the Labor Code, Page 55,", 'Correctness (1-5)': 0, 'Fluency (1-5)': 0, 'Relevance (1-5)': 0, 'Coverage(1-5)': 0, 'Short review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}
# {'idx': 4, 'Topic': 'Public Procurement', 'Complex (yes,no)': 'no', 'Question': 'What language requirements apply to public procurement procedures in Hungary according to Act CXLIII of 2015?', 'Answer': 'The Hungarian language is the primary language requirement for public procurement procedures in Hungary. According to the Act CXLIII of 2015 on public procurement, public procurement procedures shall be conducted in the Hungarian language [1]. However, contracting authorities may permit, but shall not require, the use of a language other than Hungarian [2]. \n\nExceptions to this rule include situations where the application of public procurement rules would oblige Hungary to transfer information contrary to essential interests related to State security or where the fundamental security and national security interests of Hungary cannot be guaranteed by security measures available in public procurement procedures [3]. In such cases, the language requirements may be adjusted accordingly.\n\nThe key provisions of Act CXLIII of 2015 regarding public procurement procedures include:\n\nThe Act aims to ensure transparency and public controllability of the use of public funds and establish the conditions for fair competition in public procurement procedures [1]. It also facilitates the participation of local small and medium-sized enterprises in public procurement procedures and the achievement of environmental and social objectives of the state [1].\n\nSection 5(3) and Section 62(5a) of the Act, as introduced by Act LXIII of 2016, apply to procurements and public procurement procedures launched and contracts awarded after the entry into force of the Amending Act [2].\n\nPublic procurement organisations are required to provide information under the framework of keeping contact with public procurement organisations in other Member States of the European Union, including certificates used in public procurement procedures and public databases and registers operated in Hungary [3].\n\nThe detailed rules pertaining to the authorisation of the launch and conducting the central control of public procurements undertaken by budgetary bodies and their institutions, controlled or supervised by them, are also established [4].\n\nSources:\n[1] Act CXLIII of 2015 on public procurement, Page 2, Section 6\n[2] Act CXLIII of 2015 on public procurement, Page 2\n[3] Act CXLIII of 2015 on public procurement, Page 10\n[4] Act CXLIII of 2015 on public procurement, Page 10\n[5] Act CXLIII of 2015 on public procurement, Page 10', 'Correctness (1-5)': 0, 'Fluency (1-5)': 0, 'Relevance (1-5)': 0, 'Coverage(1-5)': 0, 'Short review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}
# result_text #######  ```json
# {
#   "correct  #######
# JSON parsing error: Expecting value: line 1 column 1 (char 0)
# QUALITY SCORES #######  {'correctness': 0, 'fluency': 0, 'relevance': 0, 'coverage': 0, 'review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}  #######
# [Q3] Done - Scores: C=0, F=0, R=0, Cov=0
# [Q15] Evaluating...
# {'idx': 2, 'Topic': 'Civil Law', 'Complex (yes,no)': 'no', 'Question': 'According to the Civil Code, when does a person reach majority and what happens if a marriage is declared invalid?', 'Answer': 'A person reaches majority at the age of 18 according to the Fundamental Law [1]. However, this information is not explicitly stated in the Civil Code.\n\nRegarding the declaration of invalid marriage, the Hungarian Civil Code provides rules for this situation. According to Section 4:14 [1], a marriage may be considered as invalid if its invalidity is established by the court in an action brought for this end. A judgment establishing the invalidity of a marriage shall be effective against all [2]. An invalid marriage shall attract the legal consequences set out in this Act [3].\n\nIf the marriage is annulled, property claims may be enforced by either spouse as if the marriage had been dissolved by the court at the time of the establishment of its invalidity [4]. If its invalidity was established after the death of one of the spouses, property claims may be enforced as if the marriage had terminated upon the death of that spouse [4].\n\nAn action for annulment may be brought either during the marriage or after the termination of the marriage [5]. Unless otherwise provided in this Act, an action for annulment may be brought by either spouse, the prosecutor or any person with a legal interest in the establishment of the invalidity of the marriage [5].\n\nIf both spouses acted in good faith upon the conclusion of an invalid marriage, the property consequences of the marriage shall be identical to the property effect of a valid marriage [6].\n\nIt is worth noting that an action for annulment may be brought within six months of the termination of incapacity, starting on the day when the spouse regains his capacity to act, on the ground of having no capacity to act at the time of the conclusion of marriage [7].\n\nSources:\n[1] Fundamental Law, Page 16, Section 4\n[2] Act V of 2013 on the Civil Code, Page 112, Section 4:14\n[3] Act V of 2013 on the Civil Code, Page 112, Section 4:14\n[4] Act V of 2013 on the Civil Code, Page 117, Section 4:36\n[5] Act V of 2013 on the Civil Code, Page 112, Section 4:15\n[6] Act V of 2013 on the Civil Code, Page 117, Section 4:36\n[7] Act V of 2013 on the Civil Code, Page 113, Section 4:16', 'Correctness (1-5)': 0, 'Fluency (1-5)': 0, 'Relevance (1-5)': 0, 'Coverage(1-5)': 0, 'Short review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}
# result_text #######  ```json
# {
#   "correctness":  #######
# JSON parsing error: Expecting value: line 1 column 1 (char 0)
# QUALITY SCORES #######  {'correctness': 0, 'fluency': 0, 'relevance': 0, 'coverage': 0, 'review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}  #######
# [Q1] Done - Scores: C=0, F=0, R=0, Cov=0
# {'idx': 0, 'Topic': 'Criminal Law', 'Complex (yes,no)': 'no', 'Question': 'What is the principle of legality according to Section 1 of the Hungarian Criminal Code?', 'Answer': 'The principle of legality according to Section 1 of the Hungarian Criminal Code is that the criminal liability of the perpetrator shall be established only for an act which was punishable under an Act at the time of commission, except for acts punishable under the generally recognised rules of international law [1].\n\nSources:\n[1] Act C of 2012 on the Criminal Code, Page 2, Section 1(1)', 'Correctness (1-5)': 0, 'Fluency (1-5)': 0, 'Relevance (1-5)': 0, 'Coverage(1-5)': 0, 'Short review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}
# result_text #######  ```json
# {
#   "correctness":   #######
# JSON parsing error: Expecting value: line 1 column 1 (char 0)
# QUALITY SCORES #######  {'correctness': 0, 'fluency': 0, 'relevance': 0, 'coverage': 0, 'review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}  #######
# [Q9] Done - Scores: C=0, F=0, R=0, Cov=0
# result_text #######  ```json
# {
#   "correctness":   #######
# JSON parsing error: Expecting value: line 1 column 1 (char 0)
# QUALITY SCORES #######  {'correctness': 0, 'fluency': 0, 'relevance': 0, 'coverage': 0, 'review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}  #######
# [Q6] Done - Scores: C=0, F=0, R=0, Cov=0
# {'idx': 8, 'Topic': 'Fundamental Law', 'Complex (yes,no)': 'yes', 'Question': "Describe the core principles of Hungary's statehood including the source of power, the form of government, and the State's position on the 1949 communist constitution as stated in the National Avowal.", 'Answer': "The core principles of Hungary's statehood are based on the division of powers, as stated in Article A) of the Fundamental Law [1]. This principle ensures that no one can acquire or exercise power by force, and everyone has the right and obligation to resist such attempts in a lawful way [2]. The source of power in Hungary's government is the people, as specified in Article A) of the Fundamental Law [3]. The power shall be exercised by the people through elected representatives or, in exceptional cases, directly [4]. The form of government in Hungary is a republic, as stated in Article A) of the Fundamental Law [5]. Furthermore, Hungary's criminal law applies to acts committed by persons other than Hungarian nationals abroad, if the act constitutes a criminal offence under Hungarian law and is also punishable under the law of the place where it was committed [6]. The country also exercises some of its competences arising from the Fundamental Law jointly with other Member States, through the institutions of the European Union, to the extent necessary to exercise the rights and fulfil the obligations deriving from the Founding Treaties [7]. Moreover, Hungary bears responsibility for the fate of Hungarians living beyond its borders and shall facilitate their survival and development, support their efforts to preserve their Hungarian identity, and promote their cooperation with each other and with Hungary [8]. The National Avowal of Hungary's Fundamental Law honors the achievements of Hungary's historic constitution and the Holy Crown, which embodies the constitutional continuity of Hungary's statehood and the unity of the nation [9].\n\nSources:\n[1] Fundamental law, Page 4, Section 1\n[2] Fundamental law, Page 4, Section 2\n[3] Fundamental Law, Page 4, Article A)\n[4] Fundamental Law, Page 4, Article A) (4)\n[5] Fundamental Law, Page 4, Article A)(2)\n[6] Act C of 2012 on the Criminal Code, Page 2, Section (2)\n[7] Fundamental law, Page 5, Section (2)\n[8] Fundamental law, Page 4, Section Article A)\n[9] Fundamental Law, Page 3, NATIONAL AVOWAL", 'Correctness (1-5)': 0, 'Fluency (1-5)': 0, 'Relevance (1-5)': 0, 'Coverage(1-5)': 0, 'Short review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}
# {'idx': 5, 'Topic': 'Public Procurement', 'Complex (yes,no)': 'yes', 'Question': "How is 'innovation' defined in the Public Procurement Act, and what are the specific exclusions from the definition of a 'subcontractor'?", 'Answer': "The Public Procurement Act does not explicitly define 'innovation'. However, it mentions the 'innovation partnership' as a type of public procurement procedure that may be used for purposes specified in the Act [1]. \n\nThe specific exclusions from the definition of a 'subcontractor' are:\n\n* Any part (parts) of the concession for the fulfilment of which a tenderer (candidate) intends to use a subcontractor [1].\n* The subcontractors to be used for such parts, where already known at the time of submitting the tender or request to participate [2].\n\nBeyond these provisions, the provided documents do not specify further details on the definition of 'innovation' or exclusions from the definition of a 'subcontractor'.\n\nSources:\n[1] Act CXLIII of 2015 on public procurement, Page 97\n[2] Act CXLIII of 2015 on public procurement, Page 97", 'Correctness (1-5)': 0, 'Fluency (1-5)': 0, 'Relevance (1-5)': 0, 'Coverage(1-5)': 0, 'Short review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}
# result_text #######  ```json
# {
#   "correctness":  #######
# JSON parsing error: Expecting value: line 1 column 1 (char 0)
# QUALITY SCORES #######  {'correctness': 0, 'fluency': 0, 'relevance': 0, 'coverage': 0, 'review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}  #######
# [Q13] Done - Scores: C=0, F=0, R=0, Cov=0
# {'idx': 12, 'Topic': 'Agentic RAG Project', 'Complex (yes,no)': 'yes', 'Question': "Outline the architectural requirements for the LangGraph workflow and the specific components that must be included in the 'Értékelés és Teljesítményelemzés' (Evaluation and Performance Analysis) section.", 'Answer': "I'm a Hungarian legal assistant that can help you with:\n- Searching Hungarian legal documents for specific information\n- Calculating date differences (deadlines, timeframes)\n- Answering questions about Hungarian law from my document corpus\n\nPlease ask me a question related to these capabilities.", 'Correctness (1-5)': 0, 'Fluency (1-5)': 0, 'Relevance (1-5)': 0, 'Coverage(1-5)': 0, 'Short review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}
# result_text #######  ```json
# {
#   "correct  #######
# JSON parsing error: Expecting value: line 1 column 1 (char 0)
# QUALITY SCORES #######  {'correctness': 0, 'fluency': 0, 'relevance': 0, 'coverage': 0, 'review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}  #######
# [Q10] Done - Scores: C=0, F=0, R=0, Cov=0
# {'idx': 9, 'Topic': 'Legal Principles', 'Complex (yes,no)': 'yes', 'Question': "Compare how the principle of 'good faith and fair dealing' is described across the Civil Code, Labor Code, and Public Procurement Act.", 'Answer': "The principle of 'good faith and fair dealing' is described in the Civil Code, Labor Code, and Public Procurement Act as follows:\n\nIn the Civil Code, parties shall act upon the requirement of good faith and fair dealing when exercising rights and fulfilling obligations [1]. The requirement of good faith and fair dealing is also breached by the person whose exercise of rights is contrary to his previous conduct upon which the other party could reasonably rely on [2].\n\nIn the Labor Code, parties shall also act upon the requirement of good faith and fair dealing when exercising rights and fulfilling obligations [1]. The requirement of good faith and fair dealing is also breached by the person whose exercise of rights is contrary to his previous conduct upon which the other party could reasonably rely on [2]. Additionally, with regard to contracts between undertakings, the obligee may contest, as unfair clauses, contract terms that depart from the provisions of this section unilaterally and unreasonably to the detriment of the obligee by violating the principle of good faith and fair dealing [3]. Organisations engaged in the representation of the interests of undertakings may also contest, pursuant to the rules of the Code of Civil Procedure on actions brought in the public interest, as unfair a clause that becomes, as a standard contract term, a part of the contract between undertakings and sets forth unilaterally, unreasonably and to the detriment of the obligee the time for performance of a pecuniary debt or the rate and due date of the default interest by violating the principle of good faith and fair dealing [4].\n\nIn the Public Procurement Act, contracting authorities and economic operators shall be obliged to proceed in public procurement procedures in line with the requirements of good faith and fair dealing. The abuse of rights shall be prohibited [1]. This principle is also mentioned in the Civil Code, which states that parties shall act upon the requirement of good faith and fair dealing when exercising rights and fulfilling obligations [2]. Furthermore, the Civil Code specifies that the requirement of good faith and fair dealing is breached by the person whose exercise of rights is contrary to his previous conduct upon which the other party could reasonably rely on [3].\n\nSources:\n[1] Act V of 2013 on the Civil Code, Page 2, Section 1:3(1)\n[2] Act V of 2013 on the Civil Code, Page 2, Section 1:3(2)\n[3] Act V of 2013 on the Civil Code, Page 2, Section ", 'Correctness (1-5)': 0, 'Fluency (1-5)': 0, 'Relevance (1-5)': 0, 'Coverage(1-5)': 0, 'Short review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}
# result_text #######  ```json
# {
#   "correctness":  #######
# JSON parsing error: Expecting value: line 1 column 1 (char 0)
# QUALITY SCORES #######  {'correctness': 0, 'fluency': 0, 'relevance': 0, 'coverage': 0, 'review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}  #######
# [Q8] Done - Scores: C=0, F=0, R=0, Cov=0
# {'idx': 7, 'Topic': 'Labor Law', 'Complex (yes,no)': 'yes', 'Question': "Under what conditions can an employer restrict a worker's personal rights, and what conduct is a worker prohibited from engaging in regarding the employer's reputation and economic interests?", 'Answer': "The Hungarian Labor Code allows an employer to restrict a worker's personal rights in certain situations. According to the Fundamental Law of Hungary, the functioning of the Hungarian State shall be based on the principle of the division of powers [4]. However, no one shall act with the aim of acquiring or exercising power by force, and of exclusively possessing it [5]. Everyone shall have the right and obligation to resist such attempts in a lawful way [5].\n\nAn employer can restrict a worker's personal rights when the worker's conduct jeopardizes the employer's economic interests. The worker is prohibited from engaging in conduct that infringes upon or jeopardizes the rightful economic interests of the employer, as stated in Section 228(1) of the Act I of 2012 on the Labor Code [6]. This includes any conduct that may harm the employer's economic interests for up to two years following termination of the employment relationship.\n\nSources:\n[4] Fundamental Law, Page 4, Article A)\n[5] Fundamental Law, Page 4, Article A) (1) and (2)\n[6] Act I of 2012 on the Labor Code, Page 69, Section 228(1)", 'Correctness (1-5)': 0, 'Fluency (1-5)': 0, 'Relevance (1-5)': 0, 'Coverage(1-5)': 0, 'Short review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}
# result_text #######  ```json
# {
#   "correctness":  #######
# JSON parsing error: Expecting value: line 1 column 1 (char 0)
# QUALITY SCORES #######  {'correctness': 0, 'fluency': 0, 'relevance': 0, 'coverage': 0, 'review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}  #######
# [Q11] Done - Scores: C=0, F=0, R=0, Cov=0
# {'idx': 10, 'Topic': 'Criminal Law', 'Complex (yes,no)': 'yes', 'Question': 'In which specific cases does Hungarian criminal law apply to acts committed abroad by persons who are not Hungarian nationals?', 'Answer': 'Hungarian criminal law applies to acts committed abroad by persons who are not Hungarian nationals in the following specific cases:\n\nHungarian criminal law applies to acts committed by persons other than Hungarian nationals abroad if the act constitutes a criminal offence under Hungarian law and is also punishable under the law of the place where it was committed [1]. Additionally, Hungarian criminal law applies to acts committed by persons other than Hungarian nationals abroad against a Hungarian national, or a legal person or other legal entity without legal personality established under Hungarian law, which are punishable under the Hungarian law [2]. Furthermore, Hungarian criminal law applies to acts committed by Hungarian nationals abroad if the act constitutes a criminal offence under Hungarian law [3].\n\nSources:\n[1] Act C of 2012 on the Criminal Code, Page 2, Section 3(2)\n[2] Act C of 2012 on the Criminal Code, Page 3, Section 3\n[3] Act C of 2012 on the Criminal Code, Page 2, Section 3(1)', 'Correctness (1-5)': 0, 'Fluency (1-5)': 0, 'Relevance (1-5)': 0, 'Coverage(1-5)': 0, 'Short review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}
# result_text #######  ```json
# {
#  "correctness": 1  #######
# JSON parsing error: Expecting value: line 1 column 1 (char 0)
# QUALITY SCORES #######  {'correctness': 0, 'fluency': 0, 'relevance': 0, 'coverage': 0, 'review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}  #######
# [Q12] Done - Scores: C=0, F=0, R=0, Cov=0
# {'idx': 11, 'Topic': 'Agentic RAG Project', 'Complex (yes,no)': 'no', 'Question': "What are the requirements for the 'Modellválasztás' (Model Selection) in the Medior AI Engineer project?", 'Answer': "The requirements for the 'Modellválasztás' (Model Selection) in the Medior AI Engineer project are not explicitly mentioned in the provided documents. However, based on the content of the subtask answers, it can be inferred that the model selection process may involve the following steps:\n\n1. The Council operating within the Authority, which includes a person designated jointly by the president of the Chamber of Hungarian Engineers and the president of the Chamber of Hungarian Architects, and a person designated by the professional body of responsible accredited procurement consultants [1].\n2. The public service activity, which includes cases where the public procurement procedure of a contracting entity pursuing a drinking water-related activity is connected with a hydraulic engineering project, irrigation, or land drainage [2].\n3. The performance of the project company, which may be used as reference or turnover certifying suitability by any owner of the project company who was actually involved in such performance [3].\n\nThe process for selecting a model in the Medior AI Engineer project is not explicitly mentioned in the provided documents. However, it can be inferred that the parties used a model employment contract to conclude the occasional work employment contract, as stated in Section 60 of Act I of 2012 on the Labor Code [1].\n\nThe provided documents do not mention specific model evaluation metrics used in the Medior AI Engineer project. The topics discussed in the subtask answers are related to international law, public procurement, criminal law, and the territorial and personal scope of Hungarian law, but none of them are related to model evaluation metrics.\n\nThe Medior AI Engineer project does not have specific documentation or guidelines for model selection in the provided documents. However, there are some relevant provisions related to public procurement and selection criteria that might be applicable.\n\nAccording to Act CXLIII of 2015 on public procurement, technical specifications should ensure equal access for economic operators and not create unjustified obstacles to competition [1]. The detailed rules for determining and contents of technical specifications are laid down in a separate law [2].\n\nThe selection criteria should be clearly specified in the call for competition or in the procurement documents [3]. The contracting authority is entitled to decide not to specify any selection criteria regarding technical and professional suitability only in exceptional cases justified in the procurement documents [4]. In such cases, the application of any such selection criteria is unnecessary for adequate performance.\n\nContracting authorities should provide guidance in the procurement documents as to the level of details economic operators are required to provide in the European Single Procurement Document regarding their compliance with the selection criteria [5].\n\nSources", 'Correctness (1-5)': 0, 'Fluency (1-5)': 0, 'Relevance (1-5)': 0, 'Coverage(1-5)': 0, 'Short review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}
# result_text #######  {"correctness": 5, "flu  #######
# JSON parsing error: Unterminated string starting at: line 1 column 20 (char 19)
# QUALITY SCORES #######  {'correctness': 0, 'fluency': 0, 'relevance': 0, 'coverage': 0, 'review': 'Parse error: Unterminated string starting at: line 1 column 20 (char 19)'}  #######
# [Q14] Done - Scores: C=0, F=0, R=0, Cov=0
# {'idx': 13, 'Topic': 'Civil Law', 'Complex (yes,no)': 'no', 'Question': 'What is the legal status of a human foetus and who is entitled to request the appointment of its guardian?', 'Answer': "The legal status of a human foetus is not explicitly mentioned in the provided documents, but it implies a certain level of protection for the unborn child due to the protection and care necessary for a child's proper physical, mental, and moral development as mentioned in Article XVI of the Fundamental Law of Hungary [1, 2].\n\nThe Hungarian Civil Code (Act V of 2013) states that the guardianship authority shall appoint a guardian to the human foetus if it is necessary to protect the rights of the foetus [3]. The appointment of a guardian may be requested by a parent or grandparent of the foetus, or by the prosecutor or the local government clerk [4].\n\nSources:\n[1] Fundamental law, Page 12, Article XVI(1)\n[2] Fundamental law, Page 12, Article XVI(2)\n[3] Act V of 2013 on the Civil Code, Page 3, Section 2:3\n[4] Act V of 2013 on the Civil Code, Page 3, Section 2:3(2)", 'Correctness (1-5)': 0, 'Fluency (1-5)': 0, 'Relevance (1-5)': 0, 'Coverage(1-5)': 0, 'Short review': 'Parse error: Unterminated string starting at: line 1 column 20 (char 19)'}
# result_text #######  ```json
# {
#   "correct  #######
# JSON parsing error: Expecting value: line 1 column 1 (char 0)
# QUALITY SCORES #######  {'correctness': 0, 'fluency': 0, 'relevance': 0, 'coverage': 0, 'review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}  #######
# [Q15] Done - Scores: C=0, F=0, R=0, Cov=0
# {'idx': 14, 'Topic': 'Agentic RAG Project', 'Complex (yes,no)': 'yes', 'Question': "What are the rules for integrating 'Tools' and the 'RAG Alrendszer' (RAG Subsystem) into the agentic workflow for the Medior task?", 'Answer': "I'm a Hungarian legal assistant that can help you with:\n- Searching Hungarian legal documents for specific information\n- Calculating date differences (deadlines, timeframes)\n- Answering questions about Hungarian law from my document corpus\n\nPlease ask me a question related to these capabilities.", 'Correctness (1-5)': 0, 'Fluency (1-5)': 0, 'Relevance (1-5)': 0, 'Coverage(1-5)': 0, 'Short review': 'Parse error: Expecting value: line 1 column 1 (char 0)'}
#
# ============================================================
# Completed evaluating 15 answers!

# %% [markdown]
# ## Step 3: Save Results and Display Summary

# %%
# Create results dataframe and save to CSV
results_df = pd.DataFrame(final_results)

# Create output directory if it doesn't exist
output_dir = Path("output")
output_dir.mkdir(exist_ok=True)

# Save to CSV
output_file = output_dir / "out_quality.csv"
results_df.to_csv(output_file, sep=";", index=False)

print(f"Results saved to {output_file}")
print(f"\nTotal questions processed: {len(results_df)}")
# Out:
# Results saved to output/out_quality.csv
#
# Total questions processed: 15

# %%
# Display summary statistics
print("\n" + "="*60)
print("QUALITY METRICS SUMMARY")
print("="*60)

metrics = ["Correctness (1-5)", "Fluency (1-5)", "Relevance (1-5)", "Coverage(1-5)"]

for metric in metrics:
    if metric in results_df.columns:
        values = results_df[metric][results_df[metric] > 0]  # Exclude errors (0 values)
        if len(values) > 0:
            print(f"\n{metric}:")
            print(f"  Mean: {values.mean():.2f}")
            print(f"  Std:  {values.std():.2f}")
            print(f"  Min:  {values.min()}")
            print(f"  Max:  {values.max()}")

# Overall average
print("\n" + "-"*60)
all_scores = []
for metric in metrics:
    if metric in results_df.columns:
        all_scores.extend(results_df[metric][results_df[metric] > 0].tolist())

if all_scores:
    print(f"Overall Average Score: {sum(all_scores)/len(all_scores):.2f}")
# Out:
# ============================================================
# QUALITY METRICS SUMMARY
# ============================================================
#
# ------------------------------------------------------------

# %%
# Breakdown by complexity
print("\n" + "="*60)
print("BREAKDOWN BY COMPLEXITY")
print("="*60)

for complexity in ["yes", "no"]:
    subset = results_df[results_df["Complex (yes,no)"].str.lower() == complexity]
    if len(subset) > 0:
        print(f"\nComplex = {complexity} ({len(subset)} questions):")
        for metric in metrics:
            if metric in subset.columns:
                values = subset[metric][subset[metric] > 0]
                if len(values) > 0:
                    print(f"  {metric}: Mean={values.mean():.2f}, Std={values.std():.2f}")
# Out:
# ============================================================
# BREAKDOWN BY COMPLEXITY
# ============================================================
#
# Complex = yes (9 questions):
#
# Complex = no (6 questions):

# %%
# Breakdown by topic
print("\n" + "="*60)
print("BREAKDOWN BY TOPIC")
print("="*60)

topics = results_df["Topic"].unique()
topic_summary = []

for topic in topics:
    if pd.notna(topic) and topic.strip():
        subset = results_df[results_df["Topic"] == topic]
        if len(subset) > 0:
            avg_scores = {}
            for metric in metrics:
                if metric in subset.columns:
                    values = subset[metric][subset[metric] > 0]
                    if len(values) > 0:
                        avg_scores[metric] = values.mean()
            
            if avg_scores:
                overall_avg = sum(avg_scores.values()) / len(avg_scores)
                topic_summary.append({
                    "Topic": topic,
                    "Count": len(subset),
                    "Avg Score": overall_avg,
                    **avg_scores
                })

if topic_summary:
    topic_df = pd.DataFrame(topic_summary).sort_values("Avg Score", ascending=False)
    display(topic_df)
# Out:
# ============================================================
# BREAKDOWN BY TOPIC
# ============================================================

# %%
# Display the full results table
print("\n" + "="*60)
print("FULL RESULTS")
print("="*60)

# Display with truncated question and answer for readability
display_df = results_df.copy()
display_df["Question"] = display_df["Question"].str[:80] + "..."
display_df["Answer"] = display_df["Answer"].str[:100] + "..."
display_df["Short review"] = display_df["Short review"].str[:80] + "..."

display(display_df)
# Out:
# ============================================================
# FULL RESULTS
# ============================================================
#                   Topic Complex (yes,no)  \
# 0          Criminal Law               no
# 1          Criminal Law              yes
# 2             Civil Law               no
# 3             Civil Law              yes
# 4    Public Procurement               no
# 5    Public Procurement              yes
# 6             Labor Law               no
# 7             Labor Law              yes
# 8       Fundamental Law              yes
# 9      Legal Principles              yes
# 10         Criminal Law              yes
# 11  Agentic RAG Project               no
# 12  Agentic RAG Project              yes
# 13            Civil Law               no
# 14  Agentic RAG Project              yes
#
#                                              Question  \
# 0   What is the principle of legality according to...
# 1   Explain the difference between intentional and...
# 2   According to the Civil Code, when does a perso...
# 3   Distinguish between legal capacity and capacit...
# 4   What language requirements apply to public pro...
# 5   How is 'innovation' defined in the Public Proc...
# 6   According to Section 2 of the Labor Code, what...
# 7   Under what conditions can an employer restrict...
# 8   Describe the core principles of Hungary's stat...
# 9   Compare how the principle of 'good faith and f...
# 10  In which specific cases does Hungarian crimina...
# 11  What are the requirements for the 'Modellválas...
# 12  Outline the architectural requirements for the...
# 13  What is the legal status of a human foetus and...
# 14  What are the rules for integrating 'Tools' and...
#
#                                                Answer  Correctness (1-5)  \
# 0   The principle of legality according to Section...                  0
# 1   The difference between intentional and neglige...                  0
# 2   The Civil Code does not explicitly state when ...                  0
# 3   A minor with limited capacity to act can perfo...                  0
# 4   The language requirements for public procureme...                  0
# 5   The Public Procurement Act does not explicitly...                  0
# 6   The Hungarian Labor Code covers specific group...                  0
# 7   The Hungarian Labor Code allows employers to r...                  0
# 8   The core principles of Hungary's statehood are...                  0
# 9   The principle of 'good faith and fair dealing'...                  0
# 10  The Hungarian criminal law applies to acts com...                  0
# 11  The Hungarian Labor Code applies to work perfo...                  0
# 12  I'm a Hungarian legal assistant that can help ...                  0
# 13  The legal status of a human foetus is not expl...                  0
# 14  I'm a Hungarian legal assistant that can help ...                  0
#
#     Fluency (1-5)  Relevance (1-5)  Coverage(1-5)  \
# 0               0                0              0
# 1               0                0              0
# 2               0                0              0
# 3               0                0              0
# 4               0                0              0
# 5               0                0              0
# 6               0                0              0
# 7               0                0              0
# 8               0                0              0
# 9               0                0              0
# 10              0                0              0
# 11              0                0              0
# 12              0                0              0
# 13              0                0              0
# 14              0                0              0
#
#                                          Short review
# 0   Parse error: Unterminated string starting at: ...
# 1   Parse error: Expecting value: line 2 column 17...
# 2   Parse error: Expecting value: line 2 column 17...
# 3   Parse error: Unterminated string starting at: ...
# 4   Parse error: Expecting property name enclosed ...
# 5   Parse error: Unterminated string starting at: ...
# 6   Parse error: Expecting ',' delimiter: line 1 c...
# 7   Parse error: Expecting value: line 2 column 17...
# 8   Parse error: Unterminated string starting at: ...
# 9   Parse error: Expecting value: line 2 column 17...
# 10  Parse error: Expecting value: line 2 column 17...
# 11  Parse error: Unterminated string starting at: ...
# 12  Parse error: Expecting value: line 2 column 17...
# 13  Parse error: Unterminated string starting at: ...
# 14  Parse error: Expecting value: line 2 column 17...
