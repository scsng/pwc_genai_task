# %% [markdown]
# # Quality Testing for Agentic Workflow
#
# This notebook tests the quality of the LangGraph agentic workflow by:
# - Reading questions from `input/quality.csv`
# - Running **all questions in parallel** through the workflow to generate answers
# - Evaluating answers using Google Gemini 2.5 Flash for quality metrics:
#   - **Correctness (1-5)**: Factual accuracy of the answer
#   - **Fluency (1-5)**: Language quality and readability
#   - **Relevance (1-5)**: How well the answer addresses the question
#   - **Coverage (1-5)**: Completeness of the answer
# - Saving results to `output/out_quality.csv`

# %%
import sys
import os
import pandas as pd
from pathlib import Path
from tqdm.notebook import tqdm
import json
import concurrent.futures
from threading import Lock

# Add project root to path
project_root = Path(os.getcwd()).parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from dotenv import load_dotenv
load_dotenv(project_root / ".env", override=True)

print(f"Project root: {project_root}")
# Out:
# Project root: /home/scsng/Desktop/Projects/Job_application/pwc/pwc_genai_task

# %%
from utils.chat_client import ChatClient
from utils.agents.agentic_workflow import AgenticWorkflow
from utils.rag.vector_db import QdrantDB
from google import genai
from google.genai import types

# Initialize chat client for agentic workflow
def get_chat_client():
    return ChatClient(
        base_url=os.getenv("INFERENCE_API_URL"),
        model=os.getenv("MODEL", "default-model"),
        api_key=os.getenv("INFERENCE_API_KEY")
    )

# Initialize agentic workflow
def get_agentic_workflow():
    """Initialize the agentic workflow with LLM."""
    chat_client = get_chat_client()
    max_task_count = int(os.getenv("MAX_TASK_COUNT", "3"))
    return AgenticWorkflow(
        llm=chat_client.llm,
        vector_db=QdrantDB(
            collection_name=os.getenv("COLLECTION_NAME"),
            qdrant_host=os.getenv("QDRANT_URL"),
            embedding_model=os.getenv("EMBEDDING_MODEL"),
            qdrant_api_key=os.getenv("QDRANT_API_KEY"),
            top_k=int(os.getenv("TOP_K", "4"))
        ),
        max_task_count=max_task_count
    )

# Initialize Gemini client for quality evaluation
def get_gemini_client():
    """Initialize Google Gemini 2.5 Flash client for evaluation."""
    api_key = os.getenv("GOOGLE_API_KEY")
    if not api_key:
        raise ValueError("GOOGLE_API_KEY environment variable must be set")
    return genai.Client(api_key=api_key)

print("Initializing workflow...")
workflow = get_agentic_workflow()
print("Workflow initialized successfully!")

print("Initializing Gemini client...")
gemini_client = get_gemini_client()
print("Gemini client initialized successfully!")
# Out:
# Initializing workflow...
# /home/scsng/Desktop/Projects/Job_application/pwc/pwc_genai_task/.venv/lib/python3.13/site-packages/langchain_qdrant/qdrant.py:921: UserWarning: Api key is used with an insecure connection.
#   client = QdrantClient(**client_options)
# Workflow initialized successfully!
# Initializing Gemini client...
# Gemini client initialized successfully!

# %%
# Load quality test data
input_file = Path("input/quality.csv")
df = pd.read_csv(input_file, sep=";")

print(f"Loaded {len(df)} questions from {input_file}")
print(f"\nColumns: {list(df.columns)}")
df.head()
# Out:
# Loaded 12 questions from input/quality.csv
#
# Columns: ['Topic', 'Complex (yes,no)', 'Question', 'Answer', 'Correctness (1-5)', 'Fluency (1-5)', 'Relevance (1-5)', 'Coverage(1-5)', 'Short review']
#                 Topic Complex (yes,no)  \
# 0        Criminal Law               no
# 1        Criminal Law              yes
# 2           Civil Law               no
# 3           Civil Law              yes
# 4  Public Procurement               no
#
#                                             Question  Answer  \
# 0  What is the principle of legality according to...     NaN
# 1  Explain the difference between intentional and...     NaN
# 2  According to the Civil Code, when does a perso...     NaN
# 3  Distinguish between legal capacity and capacit...     NaN
# 4  What language requirements apply to public pro...     NaN
#
#   Correctness (1-5)  Fluency (1-5)  Relevance (1-5)  Coverage(1-5)  \
# 0               NaN            NaN              NaN            NaN
# 1               NaN            NaN              NaN            NaN
# 2               NaN            NaN              NaN            NaN
# 3               NaN            NaN              NaN            NaN
# 4               NaN            NaN              NaN            NaN
#
#    Short review
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
def generate_answer(question: str) -> str:
    """Generate an answer using the agentic workflow."""
    try:
        answer = workflow.invoke(question)
        return answer
    except Exception as e:
        print(f"Error generating answer: {e}")
        return f"Error: {e}"

# %% [markdown]
# ## Step 1: Generate Answers (Parallel)

# %%
# Process a single question for answer generation
print_lock = Lock()

def generate_single_answer(row_data: tuple) -> dict:
    """Generate answer for a single question."""
    idx, row = row_data
    topic = row.get("Topic", "")
    is_complex = row.get("Complex (yes,no)", "no")
    question = row["Question"]
    reference_answer = row.get("Answer", "")
    
    with print_lock:
        print(f"[Q{idx + 1}] Starting: {question[:60]}...")
    
    # Generate answer using agentic workflow
    generated_answer = generate_answer(question)
    
    with print_lock:
        print(f"[Q{idx + 1}] Done - Answer generated ({len(generated_answer)} chars)")
    
    return {
        "idx": idx,
        "Topic": topic,
        "Complex (yes,no)": is_complex,
        "Question": question,
        "Answer": generated_answer,
        "Reference_Answer": reference_answer
    }

# %%
# Generate answers for all questions in PARALLEL
question_col = "Question"

# Filter out empty rows
df_filtered = df[df[question_col].notna() & (df[question_col].str.strip() != "")].copy()

# Prepare data for parallel processing
rows_to_process = [(idx, row) for idx, row in df_filtered.iterrows()]

print(f"Generating answers for {len(rows_to_process)} questions in PARALLEL...\n")
print("="*60)

# Use ThreadPoolExecutor for parallel execution
MAX_WORKERS = min(len(rows_to_process), 10)  # Process up to 10 questions simultaneously

answers_results = []
with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    # Submit all tasks
    future_to_row = {executor.submit(generate_single_answer, row_data): row_data for row_data in rows_to_process}
    
    # Collect results as they complete
    for future in tqdm(concurrent.futures.as_completed(future_to_row), total=len(rows_to_process), desc="Generating Answers"):
        try:
            result = future.result()
            answers_results.append(result)
        except Exception as e:
            row_data = future_to_row[future]
            print(f"Error processing question {row_data[0]}: {e}")

# Sort results by original index to maintain order
answers_results = sorted(answers_results, key=lambda x: x["idx"])

print("\n" + "="*60)
print(f"Completed generating {len(answers_results)} answers!")
# Out:
# Generating answers for 12 questions in PARALLEL...
#
# ============================================================
# [Q1] Starting: What is the principle of legality according to Section 1 of ...
# [Q2] Starting: Explain the difference between intentional and negligent com...
# [Q3] Starting: According to the Civil Code, when does a person reach majori...
# [Q4] Starting: Distinguish between legal capacity and capacity to act under...
# [Q5] Starting: What language requirements apply to public procurement proce...
# [Q6] Starting: How is 'innovation' defined in the Public Procurement Act, a...
# [Q7] Starting: According to Section 2 of the Labor Code, what specific grou...
# [Q8] Starting: Under what conditions can an employer restrict a worker's pe...
# [Q9] Starting: Describe the core principles of Hungary's statehood includin...
# [Q10] Starting: Compare how the principle of 'good faith and fair dealing' i...
# Generating Answers:   0%|          | 0/12 [00:00<?, ?it/s]
# [Q7] Done - Answer generated (558 chars)
# [Q11] Starting: In which specific cases does Hungarian criminal law apply to...
# [Q8] Done - Answer generated (1064 chars)
# [Q12] Starting: What is the legal status of a human foetus and who is entitl...
# [Q6] Done - Answer generated (1192 chars)
# [Q4] Done - Answer generated (942 chars)
# [Q5] Done - Answer generated (442 chars)
# [Q10] Done - Answer generated (1366 chars)
# [Q1] Done - Answer generated (1271 chars)
# [Q3] Done - Answer generated (1150 chars)
# [Q9] Done - Answer generated (1536 chars)
# [Q2] Done - Answer generated (2665 chars)
# [Q12] Done - Answer generated (984 chars)
# [Q11] Done - Answer generated (920 chars)
#
# ============================================================
# Completed generating 12 answers!

# %%
# Preview generated answers
answers_df = pd.DataFrame(answers_results)
print(f"Generated {len(answers_df)} answers\n")

# Show preview
preview_df = answers_df[["idx", "Topic", "Question", "Answer"]].copy()
preview_df["Question"] = preview_df["Question"].str[:50] + "..."
preview_df["Answer"] = preview_df["Answer"].str[:80] + "..."
display(preview_df)
# Out:
# Generated 12 answers
#     idx               Topic  \
# 0     0        Criminal Law
# 1     1        Criminal Law
# 2     2           Civil Law
# 3     3           Civil Law
# 4     4  Public Procurement
# 5     5  Public Procurement
# 6     6           Labor Law
# 7     7           Labor Law
# 8     8     Fundamental Law
# 9     9    Legal Principles
# 10   10        Criminal Law
# 11   11           Civil Law
#
#                                              Question  \
# 0   What is the principle of legality according to...
# 1   Explain the difference between intentional and...
# 2   According to the Civil Code, when does a perso...
# 3   Distinguish between legal capacity and capacit...
# 4   What language requirements apply to public pro...
# 5   How is 'innovation' defined in the Public Proc...
# 6   According to Section 2 of the Labor Code, what...
# 7   Under what conditions can an employer restrict...
# 8   Describe the core principles of Hungary's stat...
# 9   Compare how the principle of 'good faith and f...
# 10  In which specific cases does Hungarian crimina...
# 11  What is the legal status of a human foetus and...
#
#                                                Answer
# 0   The principle of legality according to the Hun...
# 1   The difference between intentional and neglige...
# 2   A személy a törvényes korba a 18. életévét bet...
# 3   The legal capacity and capacity to act are two...
# 4   The Hungarian language requirements apply to p...
# 5   The Public Procurement Act does not explicitly...
# 6   The Hungarian Labor Code covers specific group...
# 7   The Hungarian Labor Code allows employers to r...
# 8   The core principles of Hungary's statehood are...
# 9   The principle of 'good faith and fair dealing'...
# 10  The Hungarian criminal law applies to acts com...
# 11  The legal status of a human foetus is not expl...

# %% [markdown]
# ## Step 2: Evaluate Answers with Gemini (Parallel)

# %%
# Quality evaluation prompt for Gemini 2.5 Flash
QUALITY_EVALUATION_PROMPT = """You are an expert evaluator assessing the quality of answers generated by an AI legal assistant.

Given a question and an answer, evaluate the answer on the following criteria (score 1-5 for each):

1. **Correctness (1-5)**: How factually accurate is the answer?
   - 1: Completely incorrect or contains major factual errors
   - 2: Contains significant errors but some correct elements
   - 3: Mostly correct with minor errors
   - 4: Correct with only trivial issues
   - 5: Completely accurate and factually correct

2. **Fluency (1-5)**: How well-written and readable is the answer?
   - 1: Incomprehensible or severely broken language
   - 2: Poor grammar/structure, hard to understand
   - 3: Acceptable but has some awkward phrasing
   - 4: Well-written with minor issues
   - 5: Excellent, professional-quality writing

3. **Relevance (1-5)**: How well does the answer address the question?
   - 1: Completely off-topic or irrelevant
   - 2: Partially relevant but misses the main point
   - 3: Addresses the question but with unnecessary tangents
   - 4: Directly relevant with minor deviations
   - 5: Perfectly addresses exactly what was asked

4. **Coverage (1-5)**: How comprehensive is the answer?
   - 1: Missing almost all important information
   - 2: Covers only a small portion of what's needed
   - 3: Covers main points but lacks important details
   - 4: Comprehensive with minor omissions
   - 5: Complete and thorough coverage

Respond ONLY with a valid JSON object in this exact format:
{"correctness": <1-5>, "fluency": <1-5>, "relevance": <1-5>, "coverage": <1-5>, "review": "<brief 1-2 sentence review>"}

Do not include any other text or explanation outside the JSON."""

def evaluate_answer_quality(question: str, answer: str, topic: str = "", reference_answer: str = "") -> dict:
    """Evaluate answer quality using Google Gemini 2.5 Flash."""
    user_content = f"Topic: {topic}\n\nQuestion: {question}\n\nAnswer to evaluate:\n{answer}"
    
    if reference_answer and pd.notna(reference_answer) and str(reference_answer).strip():
        user_content += f"\n\nReference answer (for context):\n{reference_answer}"
    
    try:
        response = gemini_client.models.generate_content(
            model="gemini-2.5-flash",
            contents=f"{QUALITY_EVALUATION_PROMPT}\n\n{user_content}",
            config=types.GenerateContentConfig(
                temperature=0.1,
                max_output_tokens=3000
            )
        )
        print("result_text ####### ",response.text," #######")
        result_text = response.text.strip()
        # Clean up the response - remove markdown code blocks if present
        if result_text.startswith("```json"):
            result_text = result_text[7:]
        if result_text.startswith("```"):
            result_text = result_text[3:]
        if result_text.endswith("```"):
            result_text = result_text[:-3]
        result_text = result_text.strip()
        
        result = json.loads(result_text)
        return {
            "correctness": int(result.get("correctness", 0)),
            "fluency": int(result.get("fluency", 0)),
            "relevance": int(result.get("relevance", 0)),
            "coverage": int(result.get("coverage", 0)),
            "review": result.get("review", "")
        }
    except json.JSONDecodeError as e:
        print(f"JSON parsing error: {e}")
        return {"correctness": 0, "fluency": 0, "relevance": 0, "coverage": 0, "review": f"Parse error: {e}"}
    except Exception as e:
        print(f"Evaluation error: {e}")
        return {"correctness": 0, "fluency": 0, "relevance": 0, "coverage": 0, "review": f"Error: {e}"}

# %%
# Evaluate a single answer
eval_print_lock = Lock()

def evaluate_single_answer(answer_data: dict) -> dict:
    """Evaluate a single answer with Gemini."""
    idx = answer_data["idx"]
    question = answer_data["Question"]
    answer = answer_data["Answer"]
    topic = answer_data["Topic"]
    reference_answer = answer_data.get("Reference_Answer", "")
    
    with eval_print_lock:
        print(f"[Q{idx + 1}] Evaluating...")
    
    # Evaluate quality using Gemini 2.5 Flash
    quality_scores = evaluate_answer_quality(
        question=question,
        answer=answer,
        topic=topic,
        reference_answer=reference_answer
    )
    print("QUALITY SCORES ####### ",quality_scores," #######")
    
    with eval_print_lock:
        print(f"[Q{idx + 1}] Done - Scores: C={quality_scores['correctness']}, F={quality_scores['fluency']}, "
              f"R={quality_scores['relevance']}, Cov={quality_scores['coverage']}")
    
    return {
        "idx": idx,
        "Topic": topic,
        "Complex (yes,no)": answer_data["Complex (yes,no)"],
        "Question": question,
        "Answer": answer,
        "Correctness (1-5)": quality_scores["correctness"],
        "Fluency (1-5)": quality_scores["fluency"],
        "Relevance (1-5)": quality_scores["relevance"],
        "Coverage(1-5)": quality_scores["coverage"],
        "Short review": quality_scores["review"]
    }

# %%
# Evaluate all answers in PARALLEL
print(f"Evaluating {len(answers_results)} answers with Gemini 2.5 Flash in PARALLEL...\n")
print("="*60)

# Use ThreadPoolExecutor for parallel evaluation
MAX_EVAL_WORKERS = min(len(answers_results), 10)  # Process up to 10 evaluations simultaneously

final_results = []
with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_EVAL_WORKERS) as executor:
    # Submit all evaluation tasks
    future_to_answer = {executor.submit(evaluate_single_answer, answer_data): answer_data for answer_data in answers_results}
    
    # Collect results as they complete
    for future in tqdm(concurrent.futures.as_completed(future_to_answer), total=len(answers_results), desc="Evaluating"):
        try:
            result = future.result()
            print(result)
            final_results.append(result)
        except Exception as e:
            answer_data = future_to_answer[future]
            print(f"Error evaluating question {answer_data['idx']}: {e}")

# Sort results by original index to maintain order
final_results = sorted(final_results, key=lambda x: x["idx"])

# Remove the idx field from results
for r in final_results:
    del r["idx"]

print("\n" + "="*60)
print(f"Completed evaluating {len(final_results)} answers!")
# Out:
# Evaluating 12 answers with Gemini 2.5 Flash in PARALLEL...
#
# ============================================================
# [Q1] Evaluating...
# [Q2] Evaluating...
# [Q3] Evaluating...
# [Q4] Evaluating...
# [Q5] Evaluating...
# [Q6] Evaluating...
# [Q7] Evaluating...
# [Q8] Evaluating...
# [Q9] Evaluating...
# [Q10] Evaluating...
# Evaluating:   0%|          | 0/12 [00:00<?, ?it/s]
# result_text #######  ```json
# {
#   "correctness": 5,
#   "fluency": 5,
#   "relevance": 5,
#   "coverage": 5,
#   "review": "The answer is completely accurate, directly addresses the question, and provides comprehensive coverage of the language requirements as stipulated in the referenced Act. The writing is clear and professional."
# }
# ```  #######
# QUALITY SCORES #######  {'correctness': 5, 'fluency': 5, 'relevance': 5, 'coverage': 5, 'review': 'The answer is completely accurate, directly addresses the question, and provides comprehensive coverage of the language requirements as stipulated in the referenced Act. The writing is clear and professional.'}  #######
# [Q5] Done - Scores: C=5, F=5, R=5, Cov=5
# [Q11] Evaluating...
# {'idx': 4, 'Topic': 'Public Procurement', 'Complex (yes,no)': 'no', 'Question': 'What language requirements apply to public procurement procedures in Hungary according to Act CXLIII of 2015?', 'Answer': 'The Hungarian language requirements apply to public procurement procedures in Hungary. According to the Act CXLIII of 2015 on public procurement, public procurement procedures shall be conducted in the Hungarian language, however, contracting authorities may also permit, but shall not be allowed to require the use of a language other than the Hungarian language [1].\n\nSources:\n[1] Act CXLIII of 2015 on public procurement, Page 2, Section 6', 'Correctness (1-5)': 5, 'Fluency (1-5)': 5, 'Relevance (1-5)': 5, 'Coverage(1-5)': 5, 'Short review': 'The answer is completely accurate, directly addresses the question, and provides comprehensive coverage of the language requirements as stipulated in the referenced Act. The writing is clear and professional.'}
# result_text #######  ```json
# {
#   "correctness": 4,
#   "fluency": 5,
#   "relevance": 5,
#   "coverage": 4,
#   "review": "The answer accurately defines the principle of legality and correctly cites the relevant sections of the Hungarian Criminal Code. While it attempts to provide constitutional context, the specific article cited from the Fundamental Law (Article T) is not the most direct one for the principle of legality itself."
# }
# ```  #######
# QUALITY SCORES #######  {'correctness': 4, 'fluency': 5, 'relevance': 5, 'coverage': 4, 'review': 'The answer accurately defines the principle of legality and correctly cites the relevant sections of the Hungarian Criminal Code. While it attempts to provide constitutional context, the specific article cited from the Fundamental Law (Article T) is not the most direct one for the principle of legality itself.'}  #######
# [Q1] Done - Scores: C=4, F=5, R=5, Cov=4
# [Q12] Evaluating...
# {'idx': 0, 'Topic': 'Criminal Law', 'Complex (yes,no)': 'no', 'Question': 'What is the principle of legality according to Section 1 of the Hungarian Criminal Code?', 'Answer': 'The principle of legality according to the Hungarian Criminal Code is that a person can only be held criminally liable for an act that was punishable by law at the time of its commission. This principle is enshrined in Section 1(1) of the Act C of 2012 on the Criminal Code, which states that "The criminal liability of the perpetrator shall be established only for an act which was punishable under an Act at the time of commission, except for acts punishable under the generally recognised rules of international law." Additionally, Section 2(2) of the same Act states that "No penalty shall be imposed and no measure shall be applied due to committing a criminal offence if it was not provided for by an Act at the time of commission or, if section 2(2) is applied, of adjudication." This principle is also reflected in Article T) of the Fundamental Law, which states that "Generally binding rules of conduct may be laid down in the Fundamental Law or in laws, adopted by an organ having legislative competence and specified in the Fundamental Law, which are promulgated in the official gazette."\n\nSources:\n[1] Act C of 2012 on the Criminal Code, Page 2, Section 1(1)\n[2] Act C of 2012 on the Criminal Code, Page 2, Section 2(2)\n[3] Fundamental Law, Page 7, Article T)', 'Correctness (1-5)': 4, 'Fluency (1-5)': 5, 'Relevance (1-5)': 5, 'Coverage(1-5)': 4, 'Short review': 'The answer accurately defines the principle of legality and correctly cites the relevant sections of the Hungarian Criminal Code. While it attempts to provide constitutional context, the specific article cited from the Fundamental Law (Article T) is not the most direct one for the principle of legality itself.'}
# result_text #######  ```json
# {
#   "correctness": 2,
#   "fluency": 5,
#   "relevance": 5,
#   "coverage": 3,
#   "review": "The answer is well-written and addresses all parts of the question. However, it contains a significant factual error regarding Hungary's position on the 1949 communist constitution, as the National Avowal explicitly rejects it, contrary to the answer's claim."
# }
# ```  #######
# QUALITY SCORES #######  {'correctness': 2, 'fluency': 5, 'relevance': 5, 'coverage': 3, 'review': "The answer is well-written and addresses all parts of the question. However, it contains a significant factual error regarding Hungary's position on the 1949 communist constitution, as the National Avowal explicitly rejects it, contrary to the answer's claim."}  #######
# [Q9] Done - Scores: C=2, F=5, R=5, Cov=3
# {'idx': 8, 'Topic': 'Fundamental Law', 'Complex (yes,no)': 'yes', 'Question': "Describe the core principles of Hungary's statehood including the source of power, the form of government, and the State's position on the 1949 communist constitution as stated in the National Avowal.", 'Answer': 'The core principles of Hungary\'s statehood are based on the division of powers and the protection of individual rights. The Fundamental Law, Article A) states that the functioning of the Hungarian State shall be based on the principle of the division of powers, and no one shall act with the aim of acquiring or exercising power by force. Everyone shall have the right and obligation to resist such attempts in a lawful way [1].\n\nHungary\'s government is a republic, as stated in Article A) of the Fundamental Law, which specifies that Hungary shall be an independent, democratic rule-of-law State with a republican form of government [2].\n\nThe source of power in Hungary\'s government is the people. According to Article A) of the Fundamental Law, the source of public power shall be the people, and the power shall be exercised by the people through elected representatives or, in exceptional cases, directly [3].\n\nHungary\'s position on the 1949 communist constitution is not explicitly mentioned in the National Avowal. However, it does state that the Hungarian people "acknowledge the sovereignty of the Hungarian people" and "declare that the Hungarian State shall be a democratic, secular, and independent republic" [4]. Beyond these provisions, the provided documents do not specify further details on Hungary\'s position on the 1949 communist constitution.\n\nSources:\n[1] Fundamental law, Page 4, Article A)\n[2] Fundamental Law, Page 4, Section A(3)\n[3] Fundamental Law, Page 23, Section 16(1)\n[4] National Avowal, Page 1, Section 1', 'Correctness (1-5)': 2, 'Fluency (1-5)': 5, 'Relevance (1-5)': 5, 'Coverage(1-5)': 3, 'Short review': "The answer is well-written and addresses all parts of the question. However, it contains a significant factual error regarding Hungary's position on the 1949 communist constitution, as the National Avowal explicitly rejects it, contrary to the answer's claim."}
# result_text #######  ```json
# {
#   "correctness": 2,
#   "fluency": 4,
#   "relevance": 2,
#   "coverage": 2,
#   "review": "The answer correctly distinguishes between legal capacity and capacity to act. However, it completely fails to address the second part of the question, instead providing irrelevant and potentially misleading information from the Hungarian Criminal Code."
# }
# ```  #######
# QUALITY SCORES #######  {'correctness': 2, 'fluency': 4, 'relevance': 2, 'coverage': 2, 'review': 'The answer correctly distinguishes between legal capacity and capacity to act. However, it completely fails to address the second part of the question, instead providing irrelevant and potentially misleading information from the Hungarian Criminal Code.'}  #######
# [Q4] Done - Scores: C=2, F=4, R=2, Cov=2
# {'idx': 3, 'Topic': 'Civil Law', 'Complex (yes,no)': 'yes', 'Question': 'Distinguish between legal capacity and capacity to act under the Civil Code. What specific juridical acts can a minor with limited capacity to act perform without their statutory representative?', 'Answer': 'The legal capacity and capacity to act are two distinct concepts under the Civil Code. Legal capacity refers to the ability of a person to have rights and obligations under the law, while capacity to act refers to the ability to perform specific legal acts, such as concluding contracts or making wills.\n\nA minor with limited capacity to act can perform certain juridical acts without their statutory representative, but the specific acts are not specified in the provided documents. However, according to the Hungarian Criminal Code, a minor with limited capacity to act can be taken away from their statutory representative without punishment, as stated in Section 211(1) of the Act C of 2012 on the Criminal Code.\n\nSources:\n[1] Civil Code, Page 10, Section 1(1)\n[2] Civil Code, Page 20, Section 3(2)\n[3] Civil Code, Page 30, Section 5(1)\n[4] Civil Code, Page 40, Section 7(3)\n[5] Act C of 2012 on the Criminal Code, Page 70, Section 211(1)', 'Correctness (1-5)': 2, 'Fluency (1-5)': 4, 'Relevance (1-5)': 2, 'Coverage(1-5)': 2, 'Short review': 'The answer correctly distinguishes between legal capacity and capacity to act. However, it completely fails to address the second part of the question, instead providing irrelevant and potentially misleading information from the Hungarian Criminal Code.'}
# result_text #######  ```json
# {
#   "correctness": 5,
#   "fluency": 5,
#   "relevance": 5,
#   "coverage": 5,
#   "review": "The answer accurately and comprehensively describes the principle of good faith and fair dealing across the specified legal acts, providing specific details and relevant citations. The writing is clear, professional, and directly addresses the comparison requested."
# }
# ```  #######
# QUALITY SCORES #######  {'correctness': 5, 'fluency': 5, 'relevance': 5, 'coverage': 5, 'review': 'The answer accurately and comprehensively describes the principle of good faith and fair dealing across the specified legal acts, providing specific details and relevant citations. The writing is clear, professional, and directly addresses the comparison requested.'}  #######
# [Q10] Done - Scores: C=5, F=5, R=5, Cov=5
# {'idx': 9, 'Topic': 'Legal Principles', 'Complex (yes,no)': 'yes', 'Question': "Compare how the principle of 'good faith and fair dealing' is described across the Civil Code, Labor Code, and Public Procurement Act.", 'Answer': "The principle of 'good faith and fair dealing' is described differently across the Civil Code, Labor Code, and Public Procurement Act.\n\nIn the Civil Code, it is described as a requirement for parties to act honestly and fairly when exercising rights and fulfilling obligations [1]. It also prohibits actions that are contrary to previous conduct that the other party could reasonably rely on [2]. Additionally, organisations can contest unfair contract terms that violate this principle [3] and [4].\n\nIn the Labor Code, this principle is a fundamental principle that employers and employees must adhere to in their interactions with each other [1]. It requires both parties to act honestly, transparently, and with integrity.\n\nIn the Public Procurement Act, the principle of 'good faith and fair dealing' is a fundamental principle that applies to all procurement procedures [1]. It requires contracting authorities and economic operators to act in good faith, transparency, and fairness in all their dealings.\n\nSources:\n[1] Act V of 2013 on the Civil Code, Page 2, Section 1:3\n[2] Act V of 2013 on the Civil Code, Page 2, Section 1:3\n[3] Act V of 2013 on the Civil Code, Page 226\n[4] Act V of 2013 on the Civil Code, Page 232\n[1] Labor Code, Page 12, Section 10(1)\n[1] Public Procurement Act, Page 12, Section 5(1)\n[2] Public Procurement Act, Page 15, Section 10(2)", 'Correctness (1-5)': 5, 'Fluency (1-5)': 5, 'Relevance (1-5)': 5, 'Coverage(1-5)': 5, 'Short review': 'The answer accurately and comprehensively describes the principle of good faith and fair dealing across the specified legal acts, providing specific details and relevant citations. The writing is clear, professional, and directly addresses the comparison requested.'}
# result_text #######  ```json
# {
#   "correctness": 2,
#   "fluency": 4,
#   "relevance": 2,
#   "coverage": 2,
#   "review": "The answer correctly defines intentional and negligent commission but then largely deviates into irrelevant general Hungarian legal principles and, critically, extensive discussions of civil law provisions when the question is specifically about criminal law. This significantly impacts its correctness and relevance, despite good fluency."
# }
# ```  #######
# QUALITY SCORES #######  {'correctness': 2, 'fluency': 4, 'relevance': 2, 'coverage': 2, 'review': 'The answer correctly defines intentional and negligent commission but then largely deviates into irrelevant general Hungarian legal principles and, critically, extensive discussions of civil law provisions when the question is specifically about criminal law. This significantly impacts its correctness and relevance, despite good fluency.'}  #######
# [Q2] Done - Scores: C=2, F=4, R=2, Cov=2
# {'idx': 1, 'Topic': 'Criminal Law', 'Complex (yes,no)': 'yes', 'Question': "Explain the difference between intentional and negligent commission of a criminal offence. How does the 'liability for result' affect qualifying circumstances?", 'Answer': "The difference between intentional and negligent commission of a criminal offence lies in the level of awareness and intent behind the act. Intentional commission refers to a situation where the perpetrator knowingly and deliberately commits an act that is punishable by law, whereas negligent commission involves a failure to exercise due care or diligence, resulting in an unintended criminal act.\n\nAccording to the Act C of 2012 on the Criminal Code, Hungarian criminal law applies to acts committed by persons other than Hungarian nationals abroad if the act constitutes a criminal offence under Hungarian law and is also punishable under the law of the place where it was committed [1]. This provision highlights the importance of intent and awareness in determining criminal liability.\n\nArticle XXVIII of the Fundamental law provides further clarification on this issue. It states that no one shall be held guilty of, or be punished for, an act which, at the time when it was committed, did not constitute a criminal offence under Hungarian law [2]. This provision suggests that negligence or lack of intent may be a mitigating factor in determining criminal liability.\n\nThe 'liability for result' affects qualifying circumstances by imposing stricter legal consequences on the perpetrator if they were at least negligent regarding the result of the criminal offense. This is stated in Section 9 of the Act C of 2012 on the Criminal Code [1]. Liability for hazardous operations is governed by Section 6:535 of the Act V of 2013 on the Civil Code [2], which holds a person carrying out hazardous activities liable for the resulting damage, unless they can prove that the damage was caused by an unavoidable event outside the scope of the hazardous activity.\n\nIn addition, Section 6:147 of the Act V of 2013 on the Civil Code [3] addresses liability in damages in the event of gratuitous contracts. The person undertaking the performance of a service free of charge is liable for the damage incurred in the subject of the service if the obligee proves that the obligor caused the damage by an intentional breach of contract, or failed to provide information on a substantial characteristic of the service which was unknown to the obligee.\n\nLastly, Section 3:59 of the Act V of 2013 on the Civil Code [4] deals with the liability of the controlling member in the event of liquidation of a controlled member of the group of companies. The controlling member is liable for the claims of creditors not yet satisfied, but can be exempted from liability if they prove that the insolvency of the controlled member was not a result of the uniform business policy of the", 'Correctness (1-5)': 2, 'Fluency (1-5)': 4, 'Relevance (1-5)': 2, 'Coverage(1-5)': 2, 'Short review': 'The answer correctly defines intentional and negligent commission but then largely deviates into irrelevant general Hungarian legal principles and, critically, extensive discussions of civil law provisions when the question is specifically about criminal law. This significantly impacts its correctness and relevance, despite good fluency.'}
# result_text #######  ```json
# {
#   "correctness": 2,
#   "fluency": 5,
#   "relevance": 3,
#   "coverage": 2,
#   "review": "The answer correctly notes that the Public Procurement Act does not explicitly define 'innovation'. However, it significantly misinterprets the second part of the question, providing information on exclusion grounds and rules for subcontractors rather than specific exclusions from the definition of a subcontractor."
# }
# ```  #######
# QUALITY SCORES #######  {'correctness': 2, 'fluency': 5, 'relevance': 3, 'coverage': 2, 'review': "The answer correctly notes that the Public Procurement Act does not explicitly define 'innovation'. However, it significantly misinterprets the second part of the question, providing information on exclusion grounds and rules for subcontractors rather than specific exclusions from the definition of a subcontractor."}  #######
# [Q6] Done - Scores: C=2, F=5, R=3, Cov=2
# {'idx': 5, 'Topic': 'Public Procurement', 'Complex (yes,no)': 'yes', 'Question': "How is 'innovation' defined in the Public Procurement Act, and what are the specific exclusions from the definition of a 'subcontractor'?", 'Answer': "The Public Procurement Act does not explicitly define 'innovation', but it mentions the 'innovation partnership' as a type of public procurement procedure [1]. The exact definition of innovation is not provided.\n\nThe specific exclusions from the definition of a 'subcontractor' include:\n\n* Any part (parts) of the concession for the fulfilment of which a tenderer (candidate) intends to use a subcontractor [1].\n* The subcontractors to be used for such parts, where already known at the time of submitting the tender or request to participate [2].\n* A tenderer, candidate, subcontractor, or organisation certifying suitability that is subject to a ground for exclusion [3].\n* A tenderer, candidate, subcontractor, or organisation certifying suitability where a ground for exclusion arises during the procedure [4].\n* Members of the board of trustees who are subject to grounds for exclusion or conflicts of interest [5].\n\nSources:\n[1] Act CXLIII of 2015 on public procurement, Page 97\n[2] Act CXLIII of 2015 on public procurement, Page 97\n[3] Act CXLIII of 2015 on public procurement, Page 58\n[4] Act CXLIII of 2015 on public procurement, Page 58\n[5] Act V of 2013 on the Civil Code, Page 106", 'Correctness (1-5)': 2, 'Fluency (1-5)': 5, 'Relevance (1-5)': 3, 'Coverage(1-5)': 2, 'Short review': "The answer correctly notes that the Public Procurement Act does not explicitly define 'innovation'. However, it significantly misinterprets the second part of the question, providing information on exclusion grounds and rules for subcontractors rather than specific exclusions from the definition of a subcontractor."}
# result_text #######  ```json
# {
#   "correctness": 2,
#   "fluency": 5,
#   "relevance": 2,
#   "coverage": 1,
#   "review": "The answer fails to address the specific section requested (Section 2), which outlines the purpose of the Act, not its scope. It incorrectly cites information from Section 3 and Section 285, with the third point being about jurisdiction rather than who is covered by the Act."
# }
# ```  #######
# QUALITY SCORES #######  {'correctness': 2, 'fluency': 5, 'relevance': 2, 'coverage': 1, 'review': 'The answer fails to address the specific section requested (Section 2), which outlines the purpose of the Act, not its scope. It incorrectly cites information from Section 3 and Section 285, with the third point being about jurisdiction rather than who is covered by the Act.'}  #######
# [Q7] Done - Scores: C=2, F=5, R=2, Cov=1
# {'idx': 6, 'Topic': 'Labor Law', 'Complex (yes,no)': 'no', 'Question': 'According to Section 2 of the Labor Code, what specific groups and entities are covered by the Act?', 'Answer': 'The Hungarian Labor Code covers specific groups and entities, including:\n\nWorkers who normally work in Hungary, unless otherwise provided [1].\nPersons who are employed by an employer with a registered office or independent establishment in Hungary [2].\nEmployees who may bring an action concerning their claims arising under Section 295 in connection with their employment in Hungary before the Hungarian court [3].\n\nSources:\n[1] Act Labor, Page 2, Section 3(1)\n[2] Act Labor, Page 2, Section 3(2)\n[3] Act I of 2012 on the Labor Code, Page 85, Section 285(4)', 'Correctness (1-5)': 2, 'Fluency (1-5)': 5, 'Relevance (1-5)': 2, 'Coverage(1-5)': 1, 'Short review': 'The answer fails to address the specific section requested (Section 2), which outlines the purpose of the Act, not its scope. It incorrectly cites information from Section 3 and Section 285, with the third point being about jurisdiction rather than who is covered by the Act.'}
# result_text #######  ```json
# {
#   "correctness": 1,
#   "fluency": 4,
#   "relevance": 2,
#   "coverage": 1,
#   "review": "The answer contains major factual errors, particularly in its explanation of employer restrictions on personal rights, where it misinterprets a Civil Code section entirely. It also misrepresents the nature of non-competition agreements and lacks comprehensive coverage of the relevant legal provisions."
# }
# ```  #######
# QUALITY SCORES #######  {'correctness': 1, 'fluency': 4, 'relevance': 2, 'coverage': 1, 'review': 'The answer contains major factual errors, particularly in its explanation of employer restrictions on personal rights, where it misinterprets a Civil Code section entirely. It also misrepresents the nature of non-competition agreements and lacks comprehensive coverage of the relevant legal provisions.'}  #######
# [Q8] Done - Scores: C=1, F=4, R=2, Cov=1
# {'idx': 7, 'Topic': 'Labor Law', 'Complex (yes,no)': 'yes', 'Question': "Under what conditions can an employer restrict a worker's personal rights, and what conduct is a worker prohibited from engaging in regarding the employer's reputation and economic interests?", 'Answer': "The Hungarian Labor Code allows employers to restrict a worker's personal rights in certain circumstances. According to Section 3:328 of the Civil Code, employers can require workers to perform mandatory juridical acts or acts relating to the cooperative without delay [3]. Additionally, written juridical acts sent by mail shall be deemed received by the recipient having his address in Hungary on the date indicated on the acknowledgement of receipt, and on the fifth working day following their dispatch if sent by registered mail, unless proven to the contrary [3].\n\nWorkers are prohibited from engaging in any conduct that may infringe upon or jeopardize the rightful economic interests of the employer for up to two years following termination of the employment relationship, as stated in Section 228(1) of the Labor Code [1]. This includes any actions that may harm the employer's reputation or economic interests.\n\nSources:\n[1] Act I of 2012 on the Labor Code, Page 69, Section 228(1)\n[2] Act V of 2013 on the Civil Code, Page 91, Section 3:328 (2) and (3)", 'Correctness (1-5)': 1, 'Fluency (1-5)': 4, 'Relevance (1-5)': 2, 'Coverage(1-5)': 1, 'Short review': 'The answer contains major factual errors, particularly in its explanation of employer restrictions on personal rights, where it misinterprets a Civil Code section entirely. It also misrepresents the nature of non-competition agreements and lacks comprehensive coverage of the relevant legal provisions.'}
# result_text #######  ```json
# {
#   "correctness": 5,
#   "fluency": 5,
#   "relevance": 5,
#   "coverage": 5,
#   "review": "The answer accurately addresses both parts of the question, clearly stating the legal status of a foetus based on the provided law and explicitly noting the absence of information regarding who can request a guardian for a foetus. It correctly cites the relevant legal provisions."
# }
# ```  #######
# QUALITY SCORES #######  {'correctness': 5, 'fluency': 5, 'relevance': 5, 'coverage': 5, 'review': 'The answer accurately addresses both parts of the question, clearly stating the legal status of a foetus based on the provided law and explicitly noting the absence of information regarding who can request a guardian for a foetus. It correctly cites the relevant legal provisions.'}  #######
# [Q12] Done - Scores: C=5, F=5, R=5, Cov=5
# {'idx': 11, 'Topic': 'Civil Law', 'Complex (yes,no)': 'no', 'Question': 'What is the legal status of a human foetus and who is entitled to request the appointment of its guardian?', 'Answer': 'The legal status of a human foetus is not explicitly mentioned in the provided documents, but it is considered a child and entitled to protection and care from the moment of conception, as stated in Article XVI of the Fundamental Law of Hungary [1]. However, the documents do not specify who is entitled to request the appointment of a guardian for a human foetus.\n\nThe Act on the Protection of Minors mentions that the court may appoint a guardian for a minor if it is in the best interests of the child [2], and the Act on Guardianship and Custody states that a guardian may be appointed for a minor if the parents are unable to care for the child [3]. Beyond these provisions, the provided documents do not specify further details on who is entitled to request the appointment of a guardian for a human foetus.\n\nSources:\n[1] Fundamental Law, Page 12, Article XVI(1)\n[2] Act on the Protection of Minors, Page 5, Section 3(1)\n[3] Act on Guardianship and Custody, Page 2, Section 2(1)', 'Correctness (1-5)': 5, 'Fluency (1-5)': 5, 'Relevance (1-5)': 5, 'Coverage(1-5)': 5, 'Short review': 'The answer accurately addresses both parts of the question, clearly stating the legal status of a foetus based on the provided law and explicitly noting the absence of information regarding who can request a guardian for a foetus. It correctly cites the relevant legal provisions.'}
# result_text #######  ```json
# {
#   "correctness": 3,
#   "fluency": 5,
#   "relevance": 3,
#   "coverage": 2,
#   "review": "The answer correctly identifies the principle of double criminality but includes an irrelevant point about 'ne bis in idem' which does not directly answer when the law applies. It also lacks comprehensive coverage of other potential grounds for extraterritorial jurisdiction over non-nationals."
# }
# ```  #######
# QUALITY SCORES #######  {'correctness': 3, 'fluency': 5, 'relevance': 3, 'coverage': 2, 'review': "The answer correctly identifies the principle of double criminality but includes an irrelevant point about 'ne bis in idem' which does not directly answer when the law applies. It also lacks comprehensive coverage of other potential grounds for extraterritorial jurisdiction over non-nationals."}  #######
# [Q11] Done - Scores: C=3, F=5, R=3, Cov=2
# {'idx': 10, 'Topic': 'Criminal Law', 'Complex (yes,no)': 'yes', 'Question': 'In which specific cases does Hungarian criminal law apply to acts committed abroad by persons who are not Hungarian nationals?', 'Answer': 'The Hungarian criminal law applies to acts committed abroad by persons who are not Hungarian nationals in the following specific cases:\n\nHungarian criminal law applies to acts committed by persons other than Hungarian nationals abroad if the act constitutes a criminal offence under Hungarian law and is also punishable under the law of the place where it was committed [1]. \n\nAdditionally, Article XXVIII of the Fundamental Law provides an exception for extraordinary cases of legal remedy laid down in an Act, where no one shall be prosecuted or convicted for a criminal offence for which they have already been finally acquitted or convicted in Hungary or, within the scope specified in an international treaty and a legal act of the European Union, in another State, as provided for by an Act [2].\n\nSources:\n[1] Act C of 2012 on the Criminal Code, Page 2, Section 3(2)\n[2] Fundamental Law, Page 15, Article XXVIII(6)', 'Correctness (1-5)': 3, 'Fluency (1-5)': 5, 'Relevance (1-5)': 3, 'Coverage(1-5)': 2, 'Short review': "The answer correctly identifies the principle of double criminality but includes an irrelevant point about 'ne bis in idem' which does not directly answer when the law applies. It also lacks comprehensive coverage of other potential grounds for extraterritorial jurisdiction over non-nationals."}
# result_text #######  ```json
# {
#   "correctness": 3,
#   "fluency": 2,
#   "relevance": 5,
#   "coverage": 3,
#   "review": "The answer correctly states the age of majority. However, the explanation regarding the consequences of an invalid marriage is poorly written, difficult to understand, and contains significant inaccuracies and omissions, especially in the convoluted final sentence."
# }
# ```  #######
# QUALITY SCORES #######  {'correctness': 3, 'fluency': 2, 'relevance': 5, 'coverage': 3, 'review': 'The answer correctly states the age of majority. However, the explanation regarding the consequences of an invalid marriage is poorly written, difficult to understand, and contains significant inaccuracies and omissions, especially in the convoluted final sentence.'}  #######
# [Q3] Done - Scores: C=3, F=2, R=5, Cov=3
# {'idx': 2, 'Topic': 'Civil Law', 'Complex (yes,no)': 'no', 'Question': 'According to the Civil Code, when does a person reach majority and what happens if a marriage is declared invalid?', 'Answer': "A személy a törvényes korba a 18. életévét betöltésekor lép be. Azaz, a személy 18. életévét betöltésekor válik törvényes korúvá.\n\nHa egy házasságot érvénytelennek nyilvánítanak, az érvénytelennek tekinthető, ha az érvénytelenítését a bíróság az érvénytelenítésre irányuló cselekmény (a továbbiakban 'érvénytelenítési eljárás') keretében állapítja meg [1]. Az érvénytelenítésről szóló ítélet mindenki számára kötelező [2]. Az érvénytelen házasság az e törvényben meghatározott jogszabályi következményeket vonja maga után [3]. Ebben az esetben, ha a házasságot érvénytelennek nyilvánítják, a feleségek bármelyike a házasság érvénytelenítéséről szóló ítélet megalapozottságának időpontjában, vagy ha az érvénytelenítését a haláluk után állapították meg, a házasság megszűnésének időpontjában, a házasság megszűnésétől számítottan a házasság megszűnésének időpontjában fennálló jogokat érvényesítheti, mintha a házasság a bíróság által megszüntetett volna [4].\n\nSources:\n[1] Act V of 2013 on the Civil Code, Page 112, Section 4:14\n[2] Act V of 2013 on the Civil Code, Page 112, Section 4:14\n[3] Act V of 2013 on the Civil Code, Page 112, Section 4:14\n[", 'Correctness (1-5)': 3, 'Fluency (1-5)': 2, 'Relevance (1-5)': 5, 'Coverage(1-5)': 3, 'Short review': 'The answer correctly states the age of majority. However, the explanation regarding the consequences of an invalid marriage is poorly written, difficult to understand, and contains significant inaccuracies and omissions, especially in the convoluted final sentence.'}
#
# ============================================================
# Completed evaluating 12 answers!

# %% [markdown]
# ## Step 3: Save Results and Display Summary

# %%
# Create results dataframe and save to CSV
results_df = pd.DataFrame(final_results)

# Create output directory if it doesn't exist
output_dir = Path("output")
output_dir.mkdir(exist_ok=True)

# Save to CSV
output_file = output_dir / "out_quality.csv"
results_df.to_csv(output_file, sep=";", index=False)

print(f"Results saved to {output_file}")
print(f"\nTotal questions processed: {len(results_df)}")
# Out:
# Results saved to output/out_quality.csv
#
# Total questions processed: 12

# %%
# Display summary statistics
print("\n" + "="*60)
print("QUALITY METRICS SUMMARY")
print("="*60)

metrics = ["Correctness (1-5)", "Fluency (1-5)", "Relevance (1-5)", "Coverage(1-5)"]

for metric in metrics:
    if metric in results_df.columns:
        values = results_df[metric][results_df[metric] > 0]  # Exclude errors (0 values)
        if len(values) > 0:
            print(f"\n{metric}:")
            print(f"  Mean: {values.mean():.2f}")
            print(f"  Std:  {values.std():.2f}")
            print(f"  Min:  {values.min()}")
            print(f"  Max:  {values.max()}")

# Overall average
print("\n" + "-"*60)
all_scores = []
for metric in metrics:
    if metric in results_df.columns:
        all_scores.extend(results_df[metric][results_df[metric] > 0].tolist())

if all_scores:
    print(f"Overall Average Score: {sum(all_scores)/len(all_scores):.2f}")
# Out:
# ============================================================
# QUALITY METRICS SUMMARY
# ============================================================
#
# Correctness (1-5):
#   Mean: 3.00
#   Std:  1.41
#   Min:  1
#   Max:  5
#
# Fluency (1-5):
#   Mean: 4.50
#   Std:  0.90
#   Min:  2
#   Max:  5
#
# Relevance (1-5):
#   Mean: 3.67
#   Std:  1.44
#   Min:  2
#   Max:  5
#
# Coverage(1-5):
#   Mean: 2.92
#   Std:  1.51
#   Min:  1
#   Max:  5
#
# ------------------------------------------------------------
# Overall Average Score: 3.52

# %%
# Breakdown by complexity
print("\n" + "="*60)
print("BREAKDOWN BY COMPLEXITY")
print("="*60)

for complexity in ["yes", "no"]:
    subset = results_df[results_df["Complex (yes,no)"].str.lower() == complexity]
    if len(subset) > 0:
        print(f"\nComplex = {complexity} ({len(subset)} questions):")
        for metric in metrics:
            if metric in subset.columns:
                values = subset[metric][subset[metric] > 0]
                if len(values) > 0:
                    print(f"  {metric}: Mean={values.mean():.2f}, Std={values.std():.2f}")
# Out:
# ============================================================
# BREAKDOWN BY COMPLEXITY
# ============================================================
#
# Complex = yes (7 questions):
#   Correctness (1-5): Mean=2.43, Std=1.27
#   Fluency (1-5): Mean=4.57, Std=0.53
#   Relevance (1-5): Mean=3.14, Std=1.35
#   Coverage(1-5): Mean=2.43, Std=1.27
#
# Complex = no (5 questions):
#   Correctness (1-5): Mean=3.80, Std=1.30
#   Fluency (1-5): Mean=4.40, Std=1.34
#   Relevance (1-5): Mean=4.40, Std=1.34
#   Coverage(1-5): Mean=3.60, Std=1.67

# %%
# Breakdown by topic
print("\n" + "="*60)
print("BREAKDOWN BY TOPIC")
print("="*60)

topics = results_df["Topic"].unique()
topic_summary = []

for topic in topics:
    if pd.notna(topic) and topic.strip():
        subset = results_df[results_df["Topic"] == topic]
        if len(subset) > 0:
            avg_scores = {}
            for metric in metrics:
                if metric in subset.columns:
                    values = subset[metric][subset[metric] > 0]
                    if len(values) > 0:
                        avg_scores[metric] = values.mean()
            
            if avg_scores:
                overall_avg = sum(avg_scores.values()) / len(avg_scores)
                topic_summary.append({
                    "Topic": topic,
                    "Count": len(subset),
                    "Avg Score": overall_avg,
                    **avg_scores
                })

if topic_summary:
    topic_df = pd.DataFrame(topic_summary).sort_values("Avg Score", ascending=False)
    display(topic_df)
# Out:
# ============================================================
# BREAKDOWN BY TOPIC
# ============================================================
#                 Topic  Count  Avg Score  Correctness (1-5)  Fluency (1-5)  \
# 5    Legal Principles      1   5.000000           5.000000       5.000000
# 2  Public Procurement      2   4.000000           3.500000       5.000000
# 4     Fundamental Law      1   3.750000           2.000000       5.000000
# 1           Civil Law      3   3.583333           3.333333       3.666667
# 0        Criminal Law      3   3.416667           3.000000       4.666667
# 3           Labor Law      2   2.250000           1.500000       4.500000
#
#    Relevance (1-5)  Coverage(1-5)
# 5         5.000000       5.000000
# 2         4.000000       3.500000
# 4         5.000000       3.000000
# 1         4.000000       3.333333
# 0         3.333333       2.666667
# 3         2.000000       1.000000

# %%
# Display the full results table
print("\n" + "="*60)
print("FULL RESULTS")
print("="*60)

# Display with truncated question and answer for readability
display_df = results_df.copy()
display_df["Question"] = display_df["Question"].str[:80] + "..."
display_df["Answer"] = display_df["Answer"].str[:100] + "..."
display_df["Short review"] = display_df["Short review"].str[:80] + "..."

display(display_df)
# Out:
# ============================================================
# FULL RESULTS
# ============================================================
#                  Topic Complex (yes,no)  \
# 0         Criminal Law               no
# 1         Criminal Law              yes
# 2            Civil Law               no
# 3            Civil Law              yes
# 4   Public Procurement               no
# 5   Public Procurement              yes
# 6            Labor Law               no
# 7            Labor Law              yes
# 8      Fundamental Law              yes
# 9     Legal Principles              yes
# 10        Criminal Law              yes
# 11           Civil Law               no
#
#                                              Question  \
# 0   What is the principle of legality according to...
# 1   Explain the difference between intentional and...
# 2   According to the Civil Code, when does a perso...
# 3   Distinguish between legal capacity and capacit...
# 4   What language requirements apply to public pro...
# 5   How is 'innovation' defined in the Public Proc...
# 6   According to Section 2 of the Labor Code, what...
# 7   Under what conditions can an employer restrict...
# 8   Describe the core principles of Hungary's stat...
# 9   Compare how the principle of 'good faith and f...
# 10  In which specific cases does Hungarian crimina...
# 11  What is the legal status of a human foetus and...
#
#                                                Answer  Correctness (1-5)  \
# 0   The principle of legality according to the Hun...                  4
# 1   The difference between intentional and neglige...                  2
# 2   A személy a törvényes korba a 18. életévét bet...                  3
# 3   The legal capacity and capacity to act are two...                  2
# 4   The Hungarian language requirements apply to p...                  5
# 5   The Public Procurement Act does not explicitly...                  2
# 6   The Hungarian Labor Code covers specific group...                  2
# 7   The Hungarian Labor Code allows employers to r...                  1
# 8   The core principles of Hungary's statehood are...                  2
# 9   The principle of 'good faith and fair dealing'...                  5
# 10  The Hungarian criminal law applies to acts com...                  3
# 11  The legal status of a human foetus is not expl...                  5
#
#     Fluency (1-5)  Relevance (1-5)  Coverage(1-5)  \
# 0               5                5              4
# 1               4                2              2
# 2               2                5              3
# 3               4                2              2
# 4               5                5              5
# 5               5                3              2
# 6               5                2              1
# 7               4                2              1
# 8               5                5              3
# 9               5                5              5
# 10              5                3              2
# 11              5                5              5
#
#                                          Short review
# 0   The answer accurately defines the principle of...
# 1   The answer correctly defines intentional and n...
# 2   The answer correctly states the age of majorit...
# 3   The answer correctly distinguishes between leg...
# 4   The answer is completely accurate, directly ad...
# 5   The answer correctly notes that the Public Pro...
# 6   The answer fails to address the specific secti...
# 7   The answer contains major factual errors, part...
# 8   The answer is well-written and addresses all p...
# 9   The answer accurately and comprehensively desc...
# 10  The answer correctly identifies the principle ...
# 11  The answer accurately addresses both parts of ...
